# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import geopandas as gpd
import googlemaps

# %%
gmaps = googlemaps.Client(key='AIzaSyAkLDXGAa9q0PxCumqHg3JV8X_aAMa-gBM')

# %%
neighbourhoods_gdf = gpd.read_file('../madrid/neighbourhoods.geojson')

# %% [markdown]
# ###### 3.1 Asignación de las atracciones turísticas a los barrios correspondientes utilizando el geojson de los barrios.

# %%
from cachetools import LRUCache

cache = LRUCache(maxsize=1000)

# %%
from tqdm import tqdm

# %%
tqdm.pandas()

neighbourhoods_gdf["attractions_neighbourhood"] = None

def get_attractions_neighborhood(row):
    places = gmaps.places(query='tourist attraction', location=row.geometry.centroid.coords[0][::-1], radius=5000)
    return places

neighbourhoods_gdf["attractions_neighbourhood"] = neighbourhoods_gdf.progress_apply(get_attractions_neighborhood, axis=1)
# Out:
# 100%|██████████| 128/128 [01:08<00:00,  1.88it/s]

# %%
neighbourhoods_gdf.head()
# Out:
#   neighbourhood neighbourhood_group  \
# 0       Palacio              Centro
# 1   Embajadores              Centro
# 2        Cortes              Centro
# 3      Justicia              Centro
# 4   Universidad              Centro
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-3.70584 40.42030, -3.70625 40...
# 1  MULTIPOLYGON (((-3.70384 40.41432, -3.70277 40...
# 2  MULTIPOLYGON (((-3.69796 40.41929, -3.69645 40...
# 3  MULTIPOLYGON (((-3.69546 40.41898, -3.69645 40...
# 4  MULTIPOLYGON (((-3.70107 40.42134, -3.70155 40...
#
#                            attractions_neighbourhood
# 0  {'html_attributions': [], 'next_page_token': '...
# 1  {'html_attributions': [], 'next_page_token': '...
# 2  {'html_attributions': [], 'next_page_token': '...
# 3  {'html_attributions': [], 'next_page_token': '...
# 4  {'html_attributions': [], 'next_page_token': '...

# %% [markdown]
# ##### 3.2 Agrupación de los barrios según su proximidad a ciertas atracciones turísticas utilizando técnicas de clustering.

# %%
def get_attraction_coordinates(attractions_dict):
    coordinates_list = []
    for result in attractions_dict['results']:
        coordinates = result['geometry']['location']
        coordinates_list.append((coordinates['lat'], coordinates['lng']))
    return coordinates_list

neighbourhoods_gdf["attraction_coordinates"] = neighbourhoods_gdf["attractions_neighbourhood"].apply(get_attraction_coordinates)

# %%
neighbourhoods_gdf.shape
# Out:
# (128, 5)

# %%
from sklearn.metrics.pairwise import haversine_distances

coordinates = neighbourhoods_gdf['attraction_coordinates']

# Convertir las coordenadas en una matriz de características
features = np.array([np.radians(coord) for coords in coordinates for coord in coords])

# Calcular la matriz de distancias
dist_matrix = haversine_distances(features, features) * 6371000/1000  # Multiplicamos por radio de la tierra en Km

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(dist_matrix)
plt.show()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
dist_pca = pca.fit_transform(dist_matrix)

# Graficar los datos en un espacio 2D
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
ax.scatter(dist_pca[:, 0], dist_pca[:, 1])
ax.set_title('PCA de matriz de distancias')
plt.show()

# %%
import json

attractions_str = neighbourhoods_gdf['attractions_neighbourhood'].apply(lambda x: json.dumps(x))
num_unique_attractions = attractions_str.nunique()

print(f'Número de etiquetas únicas de atracciones turísticas: {num_unique_attractions}')
# Out:
# Número de etiquetas únicas de atracciones turísticas: 128

# %%
for i, row in neighbourhoods_gdf.iterrows():
    attractions = []
    for place in row['attractions_neighbourhood']['results']:
        attractions.append(place['name'])
    neighbourhoods_gdf.at[i, 'attractions_neighbourhood'] = attractions

# %%
attractions_list = neighbourhoods_gdf['attractions_neighbourhood'].explode().unique().tolist()
print(attractions_list)
# Out:
# ['Plaza Mayor', 'El Retiro Park', 'TU TUK TUK Madrid', 'Tour Bernabéu', 'Temple of Debod', 'Monumento Cervantes', 'Royal Palace of Madrid', 'Paseo de las Estatuas', 'Mural by Helen Bur', 'Museo Nacional del Prado', 'Palacio de Cristal', "Let's train your dragon museum", 'Fuente de cascada', 'Torrespaña (El Pirulí)', 'Parque de Atracciones de Madrid', 'Puerta de Alcalá', 'Imprezion Tours', 'Fuente de chorros', 'Museo Nacional Centro de Arte Reina Sofía', 'Sorolla Museum', 'Catedral de la Almudena', 'calle de la sal', 'Plaza Castilla', 'Cascada Parque El Retiro', 'Semáforo , Vistas Selfies Totales', 'Jose Rizal Monument', 'Mural "Locomotora de Vapor"', 'Angel Of Madrid', 'Picnic de San Unicornio', 'Pista de hielo – Cibeles sobre hielo', 'Fuente de la Plaza de Chamberí', 'Roa', 'Maqueta Centenario de la Gran Vía', 'Mural "Contradicción"', 'Fuente de la Alcachofa', 'Playhouse', 'National Archaeological Museum', 'Mural "Paisaje de Ibiza"', 'Thyssen-Bornemisza Museum', 'Tuputamadre', 'Plaza del Gobernador', 'Mural del Bosque Encantado', 'Naval Museum', 'Manantial de la salud del arroyo de San Bernardino', 'El Cielo de Madrid Te Ama', 'Puerta de Europa', 'Estanque triple de Cuzco', 'Plaza de Pablo Picasso', 'Monte Las Tablas', 'Fountain of Fame', 'Museo Lázaro Galdiano', 'Santiago Bernabéu Stadium', 'Cuatro Estanques del Canal Isabel II', 'Fuentes gemelas en la plaza de Ciudad Lineal', 'Mural', 'Jardín Vertical Caixaforum', 'Las Curras', 'Casita del Príncipe', 'Fuente de luces', 'BALCON', 'Cuatro Torres', 'Fuente del Reloj', 'El trono de Hercules', 'El barranco de Torres', 'Welcome to Fabulous Las Matas', 'La dehesa vieja', 'Torres de Colón', 'Palacio de Zurbano', 'Lookout at the Temple of Debod', 'Palace of the Dukes of Osuna', 'La Granjita', 'El Mago Yunke - Hangar 52 Revolution', 'Paseo de la Pérgola', 'Nubes Cromáticas', 'Plaza de la Armería', 'Pingüinos del Cabo', 'Spotting Area', 'Exposición "Fascinación"', 'Cascada del parque de Cataluña', 'Great Pond of El Retiro', 'ANTICLINAL LA GAVIA', 'Fountain of the Fallen Angel', 'Fountain of Juan de Villanueva', 'Countryside House Park', 'Fuente del Cielo', 'Fountain of the Water Source', 'Cerralbo Museum', 'Sabatini Garden', 'Panorama', 'Fountain of the Birth of Water', 'Infante Don Luis Palace', 'Monumento Felix Rodriguez de la Fuente', 'Zoo Aquarium de Madrid', 'Parque de las Minas', 'Abismo Parque de Atracciones', 'Antiguo apeadero de El Plantío', 'Telesferico', 'Fortin nº 10', 'Fuente', 'Madroño cántabro', 'Los barriles de Abrantes', 'Plaza Mayor de Leganés', 'Campo del Moro', 'Plaza de la Independencia', 'Apollo Fountain', 'Mural Golondrina', 'Greenhouse Crystal Palace of Arganzuela', 'Mural a los Tercios Españoles', 'Mural Escultura Griega', 'Street Art - Mural', 'Fuentes de las Cuatro Estaciones', 'Monument to Christopher Columbus', 'Casita del Pescador', 'Estatua de Dalí', 'Avión Expoambiente', 'Jardín El Capricho de la Alameda de Osuna', 'Mirador de Aviones (LEMD)', 'Emperors Square', 'Bacchus Temple', 'Parque Juan Carlos I', 'Clock Tower of Sun Gate', 'Alhóndiga Park', 'Glorieta de Cádiz', 'Arganzuela Footbridge', 'El Dragón de Argente', 'Pisolteras', 'Puerta de la Alcarria', 'Entrevías Park', 'Callejón de la Navidad', 'Mural ALMA Boa Mistura', 'Mural feminista, homenaje al mural feminista de la Concepción', 'Dolphins Fountain', 'Real Jardín Botánico', 'Toledo Gate', 'Chorros n°1 de la Playa de Arganzuela', 'Plaza Del Gral. Vara De Rey', 'Railway Museum', 'El Oso y el Madroño', 'Arbol singular del cerro', 'Monumento al yeso en el parque del Cerro (Coslada)', 'La Santa -EscapeRoom', 'Mural Artístico del centro integral de la juventud', 'La Plaza Blanca', 'Parque del Humedal', 'Plaza de Salvador Dali', 'Gruta de la Fuente de las Ranas', 'Mirador', 'Fuente Mural', 'El baño de la Elefanta', 'Casa de la Vieja', 'El Capricho Chapel', 'Abejero de El Capricho', 'Estanques del Parque de las Naciones']

# %%
neighbourhoods_gdf.head()
# Out:
#   neighbourhood neighbourhood_group  \
# 0       Palacio              Centro
# 1   Embajadores              Centro
# 2        Cortes              Centro
# 3      Justicia              Centro
# 4   Universidad              Centro
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-3.70584 40.42030, -3.70625 40...
# 1  MULTIPOLYGON (((-3.70384 40.41432, -3.70277 40...
# 2  MULTIPOLYGON (((-3.69796 40.41929, -3.69645 40...
# 3  MULTIPOLYGON (((-3.69546 40.41898, -3.69645 40...
# 4  MULTIPOLYGON (((-3.70107 40.42134, -3.70155 40...
#
#                            attractions_neighbourhood  \
# 0  [Plaza Mayor, El Retiro Park, TU TUK TUK Madri...
# 1  [Plaza Mayor, El Retiro Park, TU TUK TUK Madri...
# 2  [Plaza Mayor, El Retiro Park, TU TUK TUK Madri...
# 3  [Plaza Mayor, El Retiro Park, TU TUK TUK Madri...
# 4  [Plaza Mayor, El Retiro Park, TU TUK TUK Madri...
#
#                               attraction_coordinates
# 0  [(40.415511, -3.7074009), (40.4152606, -3.6844...
# 1  [(40.415511, -3.7074009), (40.4152606, -3.6844...
# 2  [(40.415511, -3.7074009), (40.4152606, -3.6844...
# 3  [(40.415511, -3.7074009), (40.4152606, -3.6844...
# 4  [(40.415511, -3.7074009), (40.4152606, -3.6844...

# %%
import os

# Convierte el GeoDataFrame en una cadena GeoJSON
geojson_str = neighbourhoods_gdf.to_json()

# Guarda la cadena GeoJSON en un archivo
with open('neighbourhoods_full.geojson', 'w') as f:
    f.write(geojson_str)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Pedro Vidales\\Desktop\\ProyectX\\main'
