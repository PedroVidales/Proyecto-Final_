# %%
# %pip install transformers
# %pip install tensorflow
import tensorflow

from transformers import pipeline

# %pip install yfinance
# %pip install -U scikit-learn
# %pip install xgboost
# %pip install mwclient
# %pip install mwclient

import mwclient
import time
# Out:
# Collecting transformers
#   Using cached transformers-4.26.1-py3-none-any.whl (6.3 MB)
# Requirement already satisfied: filelock in c:\users\axell\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\axell\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\axell\anaconda3\lib\site-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.2-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\axell\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.1-py3-none-any.whl (199 kB)
#      ------------------------------------ 199.2/199.2 kB 345.5 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in c:\users\axell\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\axell\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\axell\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\axell\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\axell\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\axell\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\axell\anaconda3\lib\site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\axell\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\axell\anaconda3\lib\site-packages (from requests->transformers) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\axell\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.1 tokenizers-0.13.2 transformers-4.26.1
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10392\1433183941.py in <module>
#       1 get_ipython().run_line_magic('pip', 'install transformers')
#       2 get_ipython().run_line_magic('pip', 'install tensorflow')
# ----> 3 import tensorflow
#       4
#       5 from transformers import pipeline
#
# ModuleNotFoundError: No module named 'tensorflow'
# Collecting tensorflow
#   Using cached tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Using cached tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: packaging in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Collecting tensorboard<2.12,>=2.11
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: setuptools in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Collecting libclang>=13.0.0
#   Using cached libclang-15.0.6.1-py2.py3-none-win_amd64.whl (23.2 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\axell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 126.8 kB/s eta 0:00:00
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.3-cp39-cp39-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 3.7/3.7 MB 149.4 kB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\axell\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\axell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
#      ------------------------------------- 177.2/177.2 kB 84.1 kB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in c:\users\axell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\axell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\axell\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\axell\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\axell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\axell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\axell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\axell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\axell\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, opt-einsum, oauthlib, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.3.3 gast-0.4.0 google-auth-2.16.2 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.3 keras-2.11.0 libclang-15.0.6.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.2.0

# %%
site = mwclient.Site('en.wikipedia.org')
page = site.pages['Bitcoin']

# %%
revs = list(page.revisions())

# %%
revs[0]
# Out:
# OrderedDict([('revid', 1139935234),
#              ('parentid', 1139934627),
#              ('user', 'JLMadrigal'),
#              ('timestamp',
#               time.struct_time(tm_year=2023, tm_mon=2, tm_mday=17, tm_hour=16, tm_min=16, tm_sec=14, tm_wday=4, tm_yday=48, tm_isdst=-1)),
#              ('comment', '"add to the ledger" (clarification)')])

# %%
revs = sorted(revs, key=lambda rev: rev["timestamp"])

# %%
revs[0]
# Out:
# OrderedDict([('revid', 275832581),
#              ('parentid', 0),
#              ('user', 'Pratyeka'),
#              ('timestamp',
#               time.struct_time(tm_year=2009, tm_mon=3, tm_mday=8, tm_hour=16, tm_min=41, tm_sec=7, tm_wday=6, tm_yday=67, tm_isdst=-1)),
#              ('comment', 'creation (stub)')])

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

def find_sentiment(text):
    sent = sentiment_pipeline([text[:250]])[0]
    score = sent["score"]
    if sent["label"] == "NEGATIVE":
        score *= -1
    return score
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/268M [00:00<?, ?B/s]
# C:\Users\axell\anaconda3\anaconda3\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\axell\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
edits = {}

for rev in revs:        
    date = time.strftime("%Y-%m-%d", rev["timestamp"])
    if date not in edits:
        edits[date] = dict(sentiments=list(), edit_count=0)
    
    edits[date]["edit_count"] += 1
    
    comment = rev.get("comment", "")
    edits[date]["sentiments"].append(find_sentiment(comment))

# %%
edits
# Out:
# {'2009-03-08': {'edit_count': 4,
#   'sentiment': -0.550525039434433,
#   'neg_sentiment': 0.75},
#  '2009-08-05': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2009-08-06': {'edit_count': 2,
#   'sentiment': 0.9957457184791565,
#   'neg_sentiment': 0.0},
#  '2009-08-14': {'edit_count': 1,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2009-10-13': {'edit_count': 2,
#   'sentiment': -0.2275010645389557,
#   'neg_sentiment': 0.5},
#  '2009-11-18': {'edit_count': 1,
#   'sentiment': 0.883950412273407,
#   'neg_sentiment': 0.0},
#  '2009-12-08': {'edit_count': 1,
#   'sentiment': -0.9869275689125061,
#   'neg_sentiment': 1.0},
#  '2009-12-17': {'edit_count': 1,
#   'sentiment': -0.9975171089172363,
#   'neg_sentiment': 1.0},
#  '2010-02-23': {'edit_count': 1,
#   'sentiment': -0.9994946718215942,
#   'neg_sentiment': 1.0},
#  '2010-03-18': {'edit_count': 1,
#   'sentiment': 0.8758774995803833,
#   'neg_sentiment': 0.0},
#  '2010-04-13': {'edit_count': 4,
#   'sentiment': 0.8443553596735001,
#   'neg_sentiment': 0.0},
#  '2010-04-15': {'edit_count': 8,
#   'sentiment': 0.578101247549057,
#   'neg_sentiment': 0.125},
#  '2010-04-28': {'edit_count': 2,
#   'sentiment': -0.12094303965568542,
#   'neg_sentiment': 0.5},
#  '2010-05-13': {'edit_count': 1,
#   'sentiment': -0.9664839506149292,
#   'neg_sentiment': 1.0},
#  '2010-06-17': {'edit_count': 2,
#   'sentiment': 0.9957457184791565,
#   'neg_sentiment': 0.0},
#  '2010-06-18': {'edit_count': 9,
#   'sentiment': 0.35891860723495483,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-06-19': {'edit_count': 1,
#   'sentiment': 0.9875591397285461,
#   'neg_sentiment': 0.0},
#  '2010-06-20': {'edit_count': 3,
#   'sentiment': 0.9683797160784403,
#   'neg_sentiment': 0.0},
#  '2010-06-21': {'edit_count': 7,
#   'sentiment': 0.6157867738178798,
#   'neg_sentiment': 0.14285714285714285},
#  '2010-06-23': {'edit_count': 4,
#   'sentiment': 0.8549629300832748,
#   'neg_sentiment': 0.0},
#  '2010-06-28': {'edit_count': 4,
#   'sentiment': 0.2831639498472214,
#   'neg_sentiment': 0.25},
#  '2010-06-29': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2010-07-05': {'edit_count': 1,
#   'sentiment': 0.9360668659210205,
#   'neg_sentiment': 0.0},
#  '2010-07-07': {'edit_count': 2,
#   'sentiment': -0.1527566909790039,
#   'neg_sentiment': 0.5},
#  '2010-07-08': {'edit_count': 2,
#   'sentiment': 0.019024938344955444,
#   'neg_sentiment': 0.5},
#  '2010-07-09': {'edit_count': 1,
#   'sentiment': -0.904985249042511,
#   'neg_sentiment': 1.0},
#  '2010-07-11': {'edit_count': 13,
#   'sentiment': 0.3211618157533499,
#   'neg_sentiment': 0.3076923076923077},
#  '2010-07-12': {'edit_count': 9,
#   'sentiment': -0.28780008024639553,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-07-13': {'edit_count': 4,
#   'sentiment': 0.8065185993909836,
#   'neg_sentiment': 0.0},
#  '2010-07-14': {'edit_count': 4,
#   'sentiment': -0.06081317365169525,
#   'neg_sentiment': 0.5},
#  '2010-07-15': {'edit_count': 4,
#   'sentiment': -0.8949349820613861,
#   'neg_sentiment': 1.0},
#  '2010-07-16': {'edit_count': 6,
#   'sentiment': 0.9474905431270599,
#   'neg_sentiment': 0.0},
#  '2010-07-18': {'edit_count': 2,
#   'sentiment': -0.19054386019706726,
#   'neg_sentiment': 0.5},
#  '2010-07-19': {'edit_count': 4,
#   'sentiment': 0.8687810301780701,
#   'neg_sentiment': 0.0},
#  '2010-07-21': {'edit_count': 17,
#   'sentiment': -0.5357090339941137,
#   'neg_sentiment': 0.7647058823529411},
#  '2010-07-22': {'edit_count': 1,
#   'sentiment': -0.9933270215988159,
#   'neg_sentiment': 1.0},
#  '2010-07-25': {'edit_count': 4,
#   'sentiment': -0.062015920877456665,
#   'neg_sentiment': 0.5},
#  '2010-07-29': {'edit_count': 3,
#   'sentiment': 0.3377017378807068,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-08-03': {'edit_count': 3,
#   'sentiment': -0.9907000064849854,
#   'neg_sentiment': 1.0},
#  '2010-08-12': {'edit_count': 9,
#   'sentiment': 0.2590403093232049,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-08-14': {'edit_count': 1,
#   'sentiment': -0.9994552731513977,
#   'neg_sentiment': 1.0},
#  '2010-08-18': {'edit_count': 1,
#   'sentiment': -0.999642014503479,
#   'neg_sentiment': 1.0},
#  '2010-08-21': {'edit_count': 1,
#   'sentiment': -0.9951969981193542,
#   'neg_sentiment': 1.0},
#  '2010-09-20': {'edit_count': 1,
#   'sentiment': -0.9341223239898682,
#   'neg_sentiment': 1.0},
#  '2010-09-26': {'edit_count': 2,
#   'sentiment': -0.9957654178142548,
#   'neg_sentiment': 1.0},
#  '2010-09-27': {'edit_count': 2,
#   'sentiment': -0.9451581537723541,
#   'neg_sentiment': 1.0},
#  '2010-09-29': {'edit_count': 1,
#   'sentiment': -0.9989383816719055,
#   'neg_sentiment': 1.0},
#  '2010-10-02': {'edit_count': 1,
#   'sentiment': -0.9153555035591125,
#   'neg_sentiment': 1.0},
#  '2010-10-05': {'edit_count': 1,
#   'sentiment': -0.994151771068573,
#   'neg_sentiment': 1.0},
#  '2010-10-19': {'edit_count': 1,
#   'sentiment': 0.6267775893211365,
#   'neg_sentiment': 0.0},
#  '2010-11-10': {'edit_count': 1,
#   'sentiment': 0.9957577586174011,
#   'neg_sentiment': 0.0},
#  '2010-11-11': {'edit_count': 1,
#   'sentiment': -0.9928996562957764,
#   'neg_sentiment': 1.0},
#  '2010-11-25': {'edit_count': 1,
#   'sentiment': -0.9625310301780701,
#   'neg_sentiment': 1.0},
#  '2010-11-26': {'edit_count': 3,
#   'sentiment': -0.29696089029312134,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-11-28': {'edit_count': 1,
#   'sentiment': -0.9982038736343384,
#   'neg_sentiment': 1.0},
#  '2010-12-01': {'edit_count': 1,
#   'sentiment': 0.9957577586174011,
#   'neg_sentiment': 0.0},
#  '2010-12-05': {'edit_count': 3,
#   'sentiment': 0.2574625213940938,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-12-10': {'edit_count': 15,
#   'sentiment': 0.36348570585250856,
#   'neg_sentiment': 0.26666666666666666},
#  '2010-12-11': {'edit_count': 50,
#   'sentiment': 0.22862030029296876,
#   'neg_sentiment': 0.32},
#  '2010-12-12': {'edit_count': 17,
#   'sentiment': -0.33608103149077473,
#   'neg_sentiment': 0.6470588235294118},
#  '2010-12-13': {'edit_count': 12,
#   'sentiment': -0.8279572228590647,
#   'neg_sentiment': 0.9166666666666666},
#  '2010-12-14': {'edit_count': 49,
#   'sentiment': -0.35597571183224114,
#   'neg_sentiment': 0.6938775510204082},
#  '2010-12-15': {'edit_count': 19,
#   'sentiment': -0.1553041934967041,
#   'neg_sentiment': 0.5789473684210527},
#  '2010-12-16': {'edit_count': 11,
#   'sentiment': -0.6393263881856744,
#   'neg_sentiment': 0.8181818181818182},
#  '2010-12-17': {'edit_count': 4,
#   'sentiment': -0.8237831890583038,
#   'neg_sentiment': 1.0},
#  '2010-12-18': {'edit_count': 2,
#   'sentiment': -0.9995501041412354,
#   'neg_sentiment': 1.0},
#  '2010-12-19': {'edit_count': 5,
#   'sentiment': -0.8360068678855896,
#   'neg_sentiment': 1.0},
#  '2010-12-20': {'edit_count': 22,
#   'sentiment': -0.28941337086937646,
#   'neg_sentiment': 0.6363636363636364},
#  '2010-12-21': {'edit_count': 27,
#   'sentiment': -0.37999642116052135,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-12-22': {'edit_count': 25,
#   'sentiment': -0.4561320805549622,
#   'neg_sentiment': 0.72},
#  '2010-12-23': {'edit_count': 2,
#   'sentiment': 0.9408825039863586,
#   'neg_sentiment': 0.0},
#  '2010-12-24': {'edit_count': 1,
#   'sentiment': -0.9991777539253235,
#   'neg_sentiment': 1.0},
#  '2011-01-01': {'edit_count': 1,
#   'sentiment': 0.9105637669563293,
#   'neg_sentiment': 0.0},
#  '2011-01-06': {'edit_count': 1,
#   'sentiment': -0.9996631145477295,
#   'neg_sentiment': 1.0},
#  '2011-01-07': {'edit_count': 3,
#   'sentiment': 0.1684614618619283,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-01-10': {'edit_count': 4,
#   'sentiment': -0.06684881448745728,
#   'neg_sentiment': 0.5},
#  '2011-01-11': {'edit_count': 2,
#   'sentiment': -0.9993845224380493,
#   'neg_sentiment': 1.0},
#  '2011-01-14': {'edit_count': 2,
#   'sentiment': -0.17865556478500366,
#   'neg_sentiment': 0.5},
#  '2011-01-16': {'edit_count': 10,
#   'sentiment': -0.30195432901382446,
#   'neg_sentiment': 0.6},
#  '2011-01-17': {'edit_count': 8,
#   'sentiment': -0.06488826870918274,
#   'neg_sentiment': 0.5},
#  '2011-01-20': {'edit_count': 1,
#   'sentiment': -0.6644989252090454,
#   'neg_sentiment': 1.0},
#  '2011-01-21': {'edit_count': 6,
#   'sentiment': -0.09091725945472717,
#   'neg_sentiment': 0.5},
#  '2011-01-22': {'edit_count': 1,
#   'sentiment': -0.9456275105476379,
#   'neg_sentiment': 1.0},
#  '2011-01-24': {'edit_count': 4,
#   'sentiment': -0.47818250954151154,
#   'neg_sentiment': 0.75},
#  '2011-01-25': {'edit_count': 1,
#   'sentiment': -0.5590023398399353,
#   'neg_sentiment': 1.0},
#  '2011-01-26': {'edit_count': 1,
#   'sentiment': -0.9716882705688477,
#   'neg_sentiment': 1.0},
#  '2011-01-29': {'edit_count': 2,
#   'sentiment': -0.7818925380706787,
#   'neg_sentiment': 1.0},
#  '2011-01-31': {'edit_count': 1,
#   'sentiment': -0.9942212104797363,
#   'neg_sentiment': 1.0},
#  '2011-02-01': {'edit_count': 3,
#   'sentiment': -0.9960161050160726,
#   'neg_sentiment': 1.0},
#  '2011-02-04': {'edit_count': 1,
#   'sentiment': -0.9996967315673828,
#   'neg_sentiment': 1.0},
#  '2011-02-05': {'edit_count': 2,
#   'sentiment': -0.9946050345897675,
#   'neg_sentiment': 1.0},
#  '2011-02-06': {'edit_count': 6,
#   'sentiment': -0.692541221777598,
#   'neg_sentiment': 0.8333333333333334},
#  '2011-02-10': {'edit_count': 8,
#   'sentiment': -0.33531554043293,
#   'neg_sentiment': 0.625},
#  '2011-02-11': {'edit_count': 8,
#   'sentiment': 0.39717745780944824,
#   'neg_sentiment': 0.25},
#  '2011-02-12': {'edit_count': 5,
#   'sentiment': -0.5781579494476319,
#   'neg_sentiment': 0.8},
#  '2011-02-13': {'edit_count': 2,
#   'sentiment': -0.7603684365749359,
#   'neg_sentiment': 1.0},
#  '2011-02-14': {'edit_count': 2,
#   'sentiment': -0.9968923032283783,
#   'neg_sentiment': 1.0},
#  '2011-02-15': {'edit_count': 3,
#   'sentiment': -0.41021565596262616,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-02-17': {'edit_count': 4,
#   'sentiment': -0.0825110673904419,
#   'neg_sentiment': 0.5},
#  '2011-02-18': {'edit_count': 4,
#   'sentiment': -0.8350163698196411,
#   'neg_sentiment': 1.0},
#  '2011-02-20': {'edit_count': 1,
#   'sentiment': -0.9961812496185303,
#   'neg_sentiment': 1.0},
#  '2011-02-23': {'edit_count': 5,
#   'sentiment': 0.09343533515930176,
#   'neg_sentiment': 0.4},
#  '2011-02-24': {'edit_count': 1,
#   'sentiment': 0.9833250045776367,
#   'neg_sentiment': 0.0},
#  '2011-02-25': {'edit_count': 5,
#   'sentiment': -0.5711945295333862,
#   'neg_sentiment': 0.8},
#  '2011-02-26': {'edit_count': 2,
#   'sentiment': 0.8703858256340027,
#   'neg_sentiment': 0.0},
#  '2011-02-28': {'edit_count': 2,
#   'sentiment': 0.20266059041023254,
#   'neg_sentiment': 0.5},
#  '2011-03-01': {'edit_count': 1,
#   'sentiment': 0.804811954498291,
#   'neg_sentiment': 0.0},
#  '2011-03-04': {'edit_count': 2,
#   'sentiment': 0.8691599667072296,
#   'neg_sentiment': 0.0},
#  '2011-03-07': {'edit_count': 6,
#   'sentiment': -0.03756415843963623,
#   'neg_sentiment': 0.5},
#  '2011-03-08': {'edit_count': 4,
#   'sentiment': -0.5860636085271835,
#   'neg_sentiment': 0.75},
#  '2011-03-11': {'edit_count': 3,
#   'sentiment': 0.29068656762441,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-03-12': {'edit_count': 1,
#   'sentiment': -0.9923986792564392,
#   'neg_sentiment': 1.0},
#  '2011-03-13': {'edit_count': 1,
#   'sentiment': -0.6153936386108398,
#   'neg_sentiment': 1.0},
#  '2011-03-14': {'edit_count': 2,
#   'sentiment': -0.9953401684761047,
#   'neg_sentiment': 1.0},
#  '2011-03-15': {'edit_count': 1,
#   'sentiment': -0.9711605310440063,
#   'neg_sentiment': 1.0},
#  '2011-03-17': {'edit_count': 1,
#   'sentiment': -0.9251042008399963,
#   'neg_sentiment': 1.0},
#  '2011-03-18': {'edit_count': 2,
#   'sentiment': -0.05015981197357178,
#   'neg_sentiment': 0.5},
#  '2011-03-19': {'edit_count': 1,
#   'sentiment': -0.9962666630744934,
#   'neg_sentiment': 1.0},
#  '2011-03-20': {'edit_count': 5,
#   'sentiment': -0.592511510848999,
#   'neg_sentiment': 0.8},
#  '2011-03-21': {'edit_count': 1,
#   'sentiment': 0.804811954498291,
#   'neg_sentiment': 0.0},
#  '2011-03-22': {'edit_count': 1,
#   'sentiment': 0.804811954498291,
#   'neg_sentiment': 0.0},
#  '2011-03-23': {'edit_count': 4,
#   'sentiment': -0.49070805311203003,
#   'neg_sentiment': 0.75},
#  '2011-03-24': {'edit_count': 1,
#   'sentiment': -0.9965630173683167,
#   'neg_sentiment': 1.0},
#  '2011-03-25': {'edit_count': 8,
#   'sentiment': -0.33145761489868164,
#   'neg_sentiment': 0.625},
#  '2011-03-26': {'edit_count': 4,
#   'sentiment': -0.12413474917411804,
#   'neg_sentiment': 0.5},
#  '2011-03-28': {'edit_count': 3,
#   'sentiment': -0.39786195755004883,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-03-29': {'edit_count': 5,
#   'sentiment': -0.21896151304244996,
#   'neg_sentiment': 0.6},
#  '2011-03-30': {'edit_count': 1,
#   'sentiment': 0.8153406381607056,
#   'neg_sentiment': 0.0},
#  '2011-04-02': {'edit_count': 4,
#   'sentiment': -0.5029853731393814,
#   'neg_sentiment': 0.75},
#  '2011-04-04': {'edit_count': 4,
#   'sentiment': 0.31194327771663666,
#   'neg_sentiment': 0.25},
#  '2011-04-05': {'edit_count': 1,
#   'sentiment': -0.9985226988792419,
#   'neg_sentiment': 1.0},
#  '2011-04-06': {'edit_count': 7,
#   'sentiment': 0.33931486095700947,
#   'neg_sentiment': 0.2857142857142857},
#  '2011-04-09': {'edit_count': 2,
#   'sentiment': 0.009099960327148438,
#   'neg_sentiment': 0.5},
#  '2011-04-11': {'edit_count': 5,
#   'sentiment': -0.258244001865387,
#   'neg_sentiment': 0.6},
#  '2011-04-12': {'edit_count': 10,
#   'sentiment': 0.27081153988838197,
#   'neg_sentiment': 0.3},
#  '2011-04-13': {'edit_count': 5,
#   'sentiment': -0.6402590155601502,
#   'neg_sentiment': 0.8},
#  '2011-04-14': {'edit_count': 7,
#   'sentiment': -0.4999722072056362,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-04-16': {'edit_count': 13,
#   'sentiment': -0.3079338394678556,
#   'neg_sentiment': 0.6153846153846154},
#  '2011-04-17': {'edit_count': 2,
#   'sentiment': 0.9950544536113739,
#   'neg_sentiment': 0.0},
#  '2011-04-18': {'edit_count': 2,
#   'sentiment': -0.9971082508563995,
#   'neg_sentiment': 1.0},
#  '2011-04-19': {'edit_count': 8,
#   'sentiment': -0.492431215941906,
#   'neg_sentiment': 0.75},
#  '2011-04-20': {'edit_count': 3,
#   'sentiment': -0.9985311031341553,
#   'neg_sentiment': 1.0},
#  '2011-04-21': {'edit_count': 2,
#   'sentiment': -0.12399926781654358,
#   'neg_sentiment': 0.5},
#  '2011-04-22': {'edit_count': 3,
#   'sentiment': 0.28150580326716107,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-04-24': {'edit_count': 1,
#   'sentiment': 0.6554875373840332,
#   'neg_sentiment': 0.0},
#  '2011-04-25': {'edit_count': 1,
#   'sentiment': -0.995245635509491,
#   'neg_sentiment': 1.0},
#  '2011-04-26': {'edit_count': 3,
#   'sentiment': 0.2868928710619609,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-04-27': {'edit_count': 8,
#   'sentiment': -0.3021313026547432,
#   'neg_sentiment': 0.625},
#  '2011-04-28': {'edit_count': 3,
#   'sentiment': -0.3573858340581258,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-04-29': {'edit_count': 5,
#   'sentiment': 0.10088961124420166,
#   'neg_sentiment': 0.4},
#  '2011-04-30': {'edit_count': 1,
#   'sentiment': 0.990734338760376,
#   'neg_sentiment': 0.0},
#  '2011-05-02': {'edit_count': 5,
#   'sentiment': -0.22274836301803588,
#   'neg_sentiment': 0.6},
#  '2011-05-03': {'edit_count': 2,
#   'sentiment': 0.6941726207733154,
#   'neg_sentiment': 0.0},
#  '2011-05-04': {'edit_count': 1,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2011-05-05': {'edit_count': 12,
#   'sentiment': -0.04645408193270365,
#   'neg_sentiment': 0.5},
#  '2011-05-06': {'edit_count': 5,
#   'sentiment': -0.5827878475189209,
#   'neg_sentiment': 0.8},
#  '2011-05-08': {'edit_count': 2,
#   'sentiment': -0.9612822830677032,
#   'neg_sentiment': 1.0},
#  '2011-05-09': {'edit_count': 2,
#   'sentiment': 0.8390709161758423,
#   'neg_sentiment': 0.0},
#  '2011-05-10': {'edit_count': 1,
#   'sentiment': 0.8748217225074768,
#   'neg_sentiment': 0.0},
#  '2011-05-11': {'edit_count': 1,
#   'sentiment': 0.8748217225074768,
#   'neg_sentiment': 0.0},
#  '2011-05-12': {'edit_count': 5,
#   'sentiment': -0.272039008140564,
#   'neg_sentiment': 0.6},
#  '2011-05-14': {'edit_count': 2,
#   'sentiment': -0.15279176831245422,
#   'neg_sentiment': 0.5},
#  '2011-05-15': {'edit_count': 4,
#   'sentiment': 0.3351602703332901,
#   'neg_sentiment': 0.25},
#  '2011-05-16': {'edit_count': 7,
#   'sentiment': 0.10323899984359741,
#   'neg_sentiment': 0.42857142857142855},
#  '2011-05-17': {'edit_count': 11,
#   'sentiment': -0.16553887995806607,
#   'neg_sentiment': 0.5454545454545454},
#  '2011-05-18': {'edit_count': 10,
#   'sentiment': -0.18913403153419495,
#   'neg_sentiment': 0.6},
#  '2011-05-19': {'edit_count': 24,
#   'sentiment': -0.6198491106430689,
#   'neg_sentiment': 0.7916666666666666},
#  '2011-05-20': {'edit_count': 7,
#   'sentiment': -0.4990231394767761,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-05-21': {'edit_count': 5,
#   'sentiment': -0.594145655632019,
#   'neg_sentiment': 0.8},
#  '2011-05-22': {'edit_count': 19,
#   'sentiment': -0.5031611135131434,
#   'neg_sentiment': 0.7368421052631579},
#  '2011-05-23': {'edit_count': 9,
#   'sentiment': -0.7745044893688626,
#   'neg_sentiment': 0.8888888888888888},
#  '2011-05-24': {'edit_count': 13,
#   'sentiment': -0.5396882158059341,
#   'neg_sentiment': 0.7692307692307693},
#  '2011-05-25': {'edit_count': 8,
#   'sentiment': -0.08465516567230225,
#   'neg_sentiment': 0.5},
#  '2011-05-26': {'edit_count': 27,
#   'sentiment': -0.3999680391064397,
#   'neg_sentiment': 0.7037037037037037},
#  '2011-05-27': {'edit_count': 8,
#   'sentiment': -0.029579080641269684,
#   'neg_sentiment': 0.5},
#  '2011-05-28': {'edit_count': 7,
#   'sentiment': -0.589053043297359,
#   'neg_sentiment': 0.8571428571428571},
#  '2011-05-29': {'edit_count': 3,
#   'sentiment': -0.21549493074417114,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-05-30': {'edit_count': 5,
#   'sentiment': -0.2813817858695984,
#   'neg_sentiment': 0.6},
#  '2011-05-31': {'edit_count': 8,
#   'sentiment': -0.06665832549333572,
#   'neg_sentiment': 0.5},
#  '2011-06-01': {'edit_count': 12,
#   'sentiment': 0.4635828336079915,
#   'neg_sentiment': 0.25},
#  '2011-06-02': {'edit_count': 16,
#   'sentiment': -0.2581380419433117,
#   'neg_sentiment': 0.625},
#  '2011-06-03': {'edit_count': 41,
#   'sentiment': -0.3556325886307693,
#   'neg_sentiment': 0.6585365853658537},
#  '2011-06-04': {'edit_count': 2,
#   'sentiment': 0.0008401572704315186,
#   'neg_sentiment': 0.5},
#  '2011-06-05': {'edit_count': 9,
#   'sentiment': 0.40907244549857247,
#   'neg_sentiment': 0.2222222222222222},
#  '2011-06-06': {'edit_count': 12,
#   'sentiment': -0.8159240186214447,
#   'neg_sentiment': 0.9166666666666666},
#  '2011-06-07': {'edit_count': 5,
#   'sentiment': 0.19168769121170043,
#   'neg_sentiment': 0.4},
#  '2011-06-08': {'edit_count': 5,
#   'sentiment': 0.19756339788436889,
#   'neg_sentiment': 0.4},
#  '2011-06-09': {'edit_count': 13,
#   'sentiment': 0.32290993287013126,
#   'neg_sentiment': 0.3076923076923077},
#  '2011-06-10': {'edit_count': 7,
#   'sentiment': 0.5857171160834176,
#   'neg_sentiment': 0.14285714285714285},
#  '2011-06-11': {'edit_count': 27,
#   'sentiment': -0.654029576866715,
#   'neg_sentiment': 0.8148148148148148},
#  '2011-06-12': {'edit_count': 49,
#   'sentiment': -0.5573636536695519,
#   'neg_sentiment': 0.7755102040816326},
#  '2011-06-13': {'edit_count': 45,
#   'sentiment': -0.29170601103040905,
#   'neg_sentiment': 0.6444444444444445},
#  '2011-06-14': {'edit_count': 26,
#   'sentiment': -0.8288832238087287,
#   'neg_sentiment': 0.9230769230769231},
#  '2011-06-15': {'edit_count': 28,
#   'sentiment': -0.3627499299389975,
#   'neg_sentiment': 0.6785714285714286},
#  '2011-06-16': {'edit_count': 31,
#   'sentiment': -0.468331842653213,
#   'neg_sentiment': 0.7419354838709677},
#  '2011-06-17': {'edit_count': 50,
#   'sentiment': -0.4822886562347412,
#   'neg_sentiment': 0.74},
#  '2011-06-18': {'edit_count': 78,
#   'sentiment': -0.33036839274259716,
#   'neg_sentiment': 0.6538461538461539},
#  '2011-06-19': {'edit_count': 24,
#   'sentiment': -0.46035273124774295,
#   'neg_sentiment': 0.7083333333333334},
#  '2011-06-20': {'edit_count': 44,
#   'sentiment': -0.061401113867759705,
#   'neg_sentiment': 0.5227272727272727},
#  '2011-06-21': {'edit_count': 22,
#   'sentiment': -0.6531902009790594,
#   'neg_sentiment': 0.8181818181818182},
#  '2011-06-22': {'edit_count': 16,
#   'sentiment': -0.6408514976501465,
#   'neg_sentiment': 0.8125},
#  '2011-06-23': {'edit_count': 14,
#   'sentiment': -0.48162531001227243,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-06-24': {'edit_count': 13,
#   'sentiment': -0.46988661931111264,
#   'neg_sentiment': 0.7692307692307693},
#  '2011-06-25': {'edit_count': 8,
#   'sentiment': -0.11764965206384659,
#   'neg_sentiment': 0.5},
#  '2011-06-26': {'edit_count': 8,
#   'sentiment': -0.8833077251911163,
#   'neg_sentiment': 1.0},
#  '2011-06-27': {'edit_count': 17,
#   'sentiment': -0.20300097325268915,
#   'neg_sentiment': 0.5882352941176471},
#  '2011-06-28': {'edit_count': 2,
#   'sentiment': -0.9148067533969879,
#   'neg_sentiment': 1.0},
#  '2011-06-29': {'edit_count': 5,
#   'sentiment': -0.5984020113945008,
#   'neg_sentiment': 0.8},
#  '2011-06-30': {'edit_count': 7,
#   'sentiment': -0.4500214798109872,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-07-01': {'edit_count': 8,
#   'sentiment': -0.26348064839839935,
#   'neg_sentiment': 0.625},
#  '2011-07-02': {'edit_count': 18,
#   'sentiment': -0.21702496873007882,
#   'neg_sentiment': 0.6111111111111112},
#  '2011-07-03': {'edit_count': 7,
#   'sentiment': -0.7082808273179191,
#   'neg_sentiment': 0.8571428571428571},
#  '2011-07-04': {'edit_count': 21,
#   'sentiment': -0.24274859258106776,
#   'neg_sentiment': 0.6190476190476191},
#  '2011-07-05': {'edit_count': 4,
#   'sentiment': -0.9937281161546707,
#   'neg_sentiment': 1.0},
#  '2011-07-06': {'edit_count': 4,
#   'sentiment': -0.9985574036836624,
#   'neg_sentiment': 1.0},
#  '2011-07-07': {'edit_count': 7,
#   'sentiment': -0.46555496965135845,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-07-08': {'edit_count': 5,
#   'sentiment': 0.20583456754684448,
#   'neg_sentiment': 0.4},
#  '2011-07-09': {'edit_count': 10,
#   'sentiment': -0.596188884973526,
#   'neg_sentiment': 0.8},
#  '2011-07-10': {'edit_count': 23,
#   'sentiment': -0.6417727599973264,
#   'neg_sentiment': 0.8260869565217391},
#  '2011-07-11': {'edit_count': 3,
#   'sentiment': -0.4165908296902974,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-07-12': {'edit_count': 14,
#   'sentiment': -0.9931866526603699,
#   'neg_sentiment': 1.0},
#  '2011-07-13': {'edit_count': 4,
#   'sentiment': 0.4049360752105713,
#   'neg_sentiment': 0.25},
#  '2011-07-14': {'edit_count': 6,
#   'sentiment': -0.1022779643535614,
#   'neg_sentiment': 0.5},
#  '2011-07-15': {'edit_count': 7,
#   'sentiment': -0.9348976356642587,
#   'neg_sentiment': 1.0},
#  '2011-07-16': {'edit_count': 1,
#   'sentiment': -0.9978852868080139,
#   'neg_sentiment': 1.0},
#  '2011-07-17': {'edit_count': 1,
#   'sentiment': -0.9991002082824707,
#   'neg_sentiment': 1.0},
#  '2011-07-18': {'edit_count': 6,
#   'sentiment': 0.24837558468182883,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-07-19': {'edit_count': 9,
#   'sentiment': -0.14822868506113687,
#   'neg_sentiment': 0.5555555555555556},
#  '2011-07-21': {'edit_count': 2,
#   'sentiment': -0.9855504631996155,
#   'neg_sentiment': 1.0},
#  '2011-07-22': {'edit_count': 6,
#   'sentiment': 0.5408848226070404,
#   'neg_sentiment': 0.16666666666666666},
#  '2011-07-23': {'edit_count': 2,
#   'sentiment': -0.002204716205596924,
#   'neg_sentiment': 0.5},
#  '2011-07-24': {'edit_count': 4,
#   'sentiment': 0.46254368126392365,
#   'neg_sentiment': 0.25},
#  '2011-07-25': {'edit_count': 4,
#   'sentiment': -0.5617953091859818,
#   'neg_sentiment': 0.75},
#  '2011-07-28': {'edit_count': 4,
#   'sentiment': 0.6786458939313889,
#   'neg_sentiment': 0.0},
#  '2011-07-29': {'edit_count': 3,
#   'sentiment': -0.3353268504142761,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-07-30': {'edit_count': 2,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2011-07-31': {'edit_count': 1,
#   'sentiment': -0.9718878269195557,
#   'neg_sentiment': 1.0},
#  '2011-08-02': {'edit_count': 6,
#   'sentiment': -0.39602744579315186,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-08-03': {'edit_count': 2,
#   'sentiment': 0.0011098980903625488,
#   'neg_sentiment': 0.5},
#  '2011-08-04': {'edit_count': 2,
#   'sentiment': -0.036333322525024414,
#   'neg_sentiment': 0.5},
#  '2011-08-05': {'edit_count': 4,
#   'sentiment': 0.31124943494796753,
#   'neg_sentiment': 0.25},
#  '2011-08-07': {'edit_count': 4,
#   'sentiment': -0.5111590623855591,
#   'neg_sentiment': 0.75},
#  '2011-08-08': {'edit_count': 4,
#   'sentiment': -0.5418856292963028,
#   'neg_sentiment': 0.75},
#  '2011-08-09': {'edit_count': 3,
#   'sentiment': -0.4091400106747945,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-08-10': {'edit_count': 5,
#   'sentiment': 0.17298108339309692,
#   'neg_sentiment': 0.4},
#  '2011-08-11': {'edit_count': 12,
#   'sentiment': -0.5211661458015442,
#   'neg_sentiment': 0.75},
#  '2011-08-12': {'edit_count': 4,
#   'sentiment': -0.006856516003608704,
#   'neg_sentiment': 0.5},
#  '2011-08-15': {'edit_count': 1,
#   'sentiment': -0.9994683861732483,
#   'neg_sentiment': 1.0},
#  '2011-08-16': {'edit_count': 1,
#   'sentiment': -0.9736192226409912,
#   'neg_sentiment': 1.0},
#  '2011-08-17': {'edit_count': 8,
#   'sentiment': 0.19313526898622513,
#   'neg_sentiment': 0.375},
#  '2011-08-19': {'edit_count': 3,
#   'sentiment': -0.9930854042371114,
#   'neg_sentiment': 1.0},
#  '2011-08-20': {'edit_count': 9,
#   'sentiment': -0.14824428823259142,
#   'neg_sentiment': 0.5555555555555556},
#  '2011-08-22': {'edit_count': 7,
#   'sentiment': -0.39773727314812796,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-08-23': {'edit_count': 7,
#   'sentiment': -0.6737942865916661,
#   'neg_sentiment': 0.8571428571428571},
#  '2011-08-24': {'edit_count': 4,
#   'sentiment': -0.9043555408716202,
#   'neg_sentiment': 1.0},
#  '2011-08-25': {'edit_count': 1,
#   'sentiment': -0.967137336730957,
#   'neg_sentiment': 1.0},
#  '2011-08-26': {'edit_count': 2,
#   'sentiment': -0.9959077835083008,
#   'neg_sentiment': 1.0},
#  '2011-08-27': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2011-08-31': {'edit_count': 1,
#   'sentiment': 0.8748217225074768,
#   'neg_sentiment': 0.0},
#  '2011-09-01': {'edit_count': 6,
#   'sentiment': -0.039308389027913414,
#   'neg_sentiment': 0.5},
#  '2011-09-02': {'edit_count': 2,
#   'sentiment': -0.9967594742774963,
#   'neg_sentiment': 1.0},
#  '2011-09-03': {'edit_count': 3,
#   'sentiment': -0.40880874792734784,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-09-04': {'edit_count': 1,
#   'sentiment': 0.9889422655105591,
#   'neg_sentiment': 0.0},
#  '2011-09-05': {'edit_count': 1,
#   'sentiment': -0.9876619577407837,
#   'neg_sentiment': 1.0},
#  '2011-09-06': {'edit_count': 1,
#   'sentiment': -0.9993465542793274,
#   'neg_sentiment': 1.0},
#  '2011-09-07': {'edit_count': 6,
#   'sentiment': 0.3016740580399831,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-09-08': {'edit_count': 1,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2011-09-09': {'edit_count': 3,
#   'sentiment': -0.9937077760696411,
#   'neg_sentiment': 1.0},
#  '2011-09-13': {'edit_count': 9,
#   'sentiment': -0.36453882190916276,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-09-14': {'edit_count': 4,
#   'sentiment': 7.21663236618042e-05,
#   'neg_sentiment': 0.5},
#  '2011-09-15': {'edit_count': 4,
#   'sentiment': -0.024755284190177917,
#   'neg_sentiment': 0.5},
#  '2011-09-16': {'edit_count': 8,
#   'sentiment': -0.5184009298682213,
#   'neg_sentiment': 0.75},
#  '2011-09-17': {'edit_count': 7,
#   'sentiment': -0.9975740483828953,
#   'neg_sentiment': 1.0},
#  '2011-09-18': {'edit_count': 1,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2011-09-19': {'edit_count': 5,
#   'sentiment': 0.18618898391723632,
#   'neg_sentiment': 0.4},
#  '2011-09-20': {'edit_count': 2,
#   'sentiment': -0.16116780042648315,
#   'neg_sentiment': 0.5},
#  '2011-09-21': {'edit_count': 6,
#   'sentiment': -0.0559638241926829,
#   'neg_sentiment': 0.5},
#  '2011-09-22': {'edit_count': 3,
#   'sentiment': -0.98243115345637,
#   'neg_sentiment': 1.0},
#  '2011-09-25': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2011-09-26': {'edit_count': 2,
#   'sentiment': -0.013261735439300537,
#   'neg_sentiment': 0.5},
#  '2011-09-27': {'edit_count': 4,
#   'sentiment': 0.011409446597099304,
#   'neg_sentiment': 0.5},
#  '2011-09-29': {'edit_count': 4,
#   'sentiment': -0.9252558797597885,
#   'neg_sentiment': 1.0},
#  '2011-09-30': {'edit_count': 2,
#   'sentiment': -0.048456043004989624,
#   'neg_sentiment': 0.5},
#  '2011-10-01': {'edit_count': 2,
#   'sentiment': -0.17213919758796692,
#   'neg_sentiment': 0.5},
#  '2011-10-02': {'edit_count': 19,
#   'sentiment': -0.27649953804518046,
#   'neg_sentiment': 0.631578947368421},
#  '2011-10-04': {'edit_count': 1,
#   'sentiment': 0.951126754283905,
#   'neg_sentiment': 0.0},
#  '2011-10-05': {'edit_count': 4,
#   'sentiment': -0.5468907505273819,
#   'neg_sentiment': 0.75},
#  '2011-10-06': {'edit_count': 2,
#   'sentiment': -0.7648929953575134,
#   'neg_sentiment': 1.0},
#  '2011-10-07': {'edit_count': 5,
#   'sentiment': 0.0973158597946167,
#   'neg_sentiment': 0.4},
#  '2011-10-08': {'edit_count': 4,
#   'sentiment': -0.43469488620758057,
#   'neg_sentiment': 0.75},
#  '2011-10-09': {'edit_count': 9,
#   'sentiment': 0.4437045322524177,
#   'neg_sentiment': 0.2222222222222222},
#  '2011-10-10': {'edit_count': 6,
#   'sentiment': 0.3610907296339671,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-10-11': {'edit_count': 3,
#   'sentiment': -0.3952216108640035,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-13': {'edit_count': 2,
#   'sentiment': -0.034446388483047485,
#   'neg_sentiment': 0.5},
#  '2011-10-15': {'edit_count': 3,
#   'sentiment': -0.3490292429924011,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-16': {'edit_count': 2,
#   'sentiment': -0.01834121346473694,
#   'neg_sentiment': 0.5},
#  '2011-10-17': {'edit_count': 2,
#   'sentiment': -0.1255081295967102,
#   'neg_sentiment': 0.5},
#  '2011-10-18': {'edit_count': 7,
#   'sentiment': 0.02461344003677368,
#   'neg_sentiment': 0.42857142857142855},
#  '2011-10-19': {'edit_count': 2,
#   'sentiment': -0.1255415678024292,
#   'neg_sentiment': 0.5},
#  '2011-10-20': {'edit_count': 3,
#   'sentiment': 0.2530330419540405,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-10-23': {'edit_count': 9,
#   'sentiment': -0.533316883775923,
#   'neg_sentiment': 0.7777777777777778},
#  '2011-10-24': {'edit_count': 4,
#   'sentiment': -0.09807746112346649,
#   'neg_sentiment': 0.5},
#  '2011-10-25': {'edit_count': 3,
#   'sentiment': -0.3396069407463074,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-27': {'edit_count': 3,
#   'sentiment': 0.22940913836161295,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-10-28': {'edit_count': 3,
#   'sentiment': -0.27442042032877606,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-30': {'edit_count': 3,
#   'sentiment': -0.3578834335009257,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-31': {'edit_count': 1,
#   'sentiment': -0.9982296824455261,
#   'neg_sentiment': 1.0},
#  '2011-11-01': {'edit_count': 4,
#   'sentiment': -0.5172293037176132,
#   'neg_sentiment': 0.75},
#  '2011-11-03': {'edit_count': 3,
#   'sentiment': 0.23611690600713095,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-11-04': {'edit_count': 1,
#   'sentiment': -0.9993987083435059,
#   'neg_sentiment': 1.0},
#  '2011-11-05': {'edit_count': 1,
#   'sentiment': -0.9985162615776062,
#   'neg_sentiment': 1.0},
#  '2011-11-06': {'edit_count': 1,
#   'sentiment': -0.819525957107544,
#   'neg_sentiment': 1.0},
#  '2011-11-12': {'edit_count': 3,
#   'sentiment': -0.4013414184252421,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-11-13': {'edit_count': 16,
#   'sentiment': -0.6052790470421314,
#   'neg_sentiment': 0.8125},
#  '2011-11-14': {'edit_count': 12,
#   'sentiment': -0.0167665829261144,
#   'neg_sentiment': 0.5},
#  '2011-11-15': {'edit_count': 2,
#   'sentiment': -0.9895029962062836,
#   'neg_sentiment': 1.0},
#  '2011-11-18': {'edit_count': 1,
#   'sentiment': -0.9997937083244324,
#   'neg_sentiment': 1.0},
#  '2011-11-20': {'edit_count': 2,
#   'sentiment': -0.11405503749847412,
#   'neg_sentiment': 0.5},
#  '2011-11-21': {'edit_count': 1,
#   'sentiment': 0.9894212484359741,
#   'neg_sentiment': 0.0},
#  '2011-11-22': {'edit_count': 3,
#   'sentiment': -0.4140034317970276,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-11-23': {'edit_count': 1,
#   'sentiment': -0.9409189820289612,
#   'neg_sentiment': 1.0},
#  '2011-11-25': {'edit_count': 3,
#   'sentiment': -0.9348680178324381,
#   'neg_sentiment': 1.0},
#  '2011-11-26': {'edit_count': 7,
#   'sentiment': 0.669659503868648,
#   'neg_sentiment': 0.0},
#  '2011-11-27': {'edit_count': 3,
#   'sentiment': 0.17245028416315714,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-11-28': {'edit_count': 2,
#   'sentiment': -0.8722028136253357,
#   'neg_sentiment': 1.0},
#  '2011-11-29': {'edit_count': 2,
#   'sentiment': -0.029572665691375732,
#   'neg_sentiment': 0.5},
#  '2011-11-30': {'edit_count': 2,
#   'sentiment': 0.951126754283905,
#   'neg_sentiment': 0.0},
#  '2011-12-01': {'edit_count': 4,
#   'sentiment': -0.5097888112068176,
#   'neg_sentiment': 0.75},
#  '2011-12-02': {'edit_count': 1,
#   'sentiment': -0.9950590133666992,
#   'neg_sentiment': 1.0},
#  '2011-12-04': {'edit_count': 1,
#   'sentiment': -0.9997431635856628,
#   'neg_sentiment': 1.0},
#  '2011-12-05': {'edit_count': 4,
#   'sentiment': -0.5105186253786087,
#   'neg_sentiment': 0.75},
#  '2011-12-06': {'edit_count': 2,
#   'sentiment': 0.8080736994743347,
#   'neg_sentiment': 0.0},
#  '2011-12-07': {'edit_count': 2,
#   'sentiment': -0.028262019157409668,
#   'neg_sentiment': 0.5},
#  '2011-12-09': {'edit_count': 2,
#   'sentiment': -0.15644678473472595,
#   'neg_sentiment': 0.5},
#  '2011-12-10': {'edit_count': 2,
#   'sentiment': -0.8316272497177124,
#   'neg_sentiment': 1.0},
#  '2011-12-12': {'edit_count': 1,
#   'sentiment': -0.8184986710548401,
#   'neg_sentiment': 1.0},
#  '2011-12-13': {'edit_count': 1,
#   'sentiment': -0.7921814322471619,
#   'neg_sentiment': 1.0},
#  '2011-12-15': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2011-12-17': {'edit_count': 2,
#   'sentiment': -0.12560635805130005,
#   'neg_sentiment': 0.5},
#  '2011-12-18': {'edit_count': 3,
#   'sentiment': -0.7694339553515116,
#   'neg_sentiment': 1.0},
#  '2011-12-20': {'edit_count': 3,
#   'sentiment': -0.3493914206822713,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-12-21': {'edit_count': 5,
#   'sentiment': -0.5931655883789062,
#   'neg_sentiment': 0.8},
#  '2011-12-22': {'edit_count': 2,
#   'sentiment': 0.09328970313072205,
#   'neg_sentiment': 0.5},
#  '2011-12-23': {'edit_count': 1,
#   'sentiment': -0.9966468214988708,
#   'neg_sentiment': 1.0},
#  '2011-12-24': {'edit_count': 1,
#   'sentiment': 0.9518775939941406,
#   'neg_sentiment': 0.0},
#  '2011-12-25': {'edit_count': 1,
#   'sentiment': -0.9957411289215088,
#   'neg_sentiment': 1.0},
#  '2011-12-26': {'edit_count': 3,
#   'sentiment': -0.32774649063746136,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-12-28': {'edit_count': 1,
#   'sentiment': -0.9964214563369751,
#   'neg_sentiment': 1.0},
#  '2011-12-29': {'edit_count': 1,
#   'sentiment': -0.9993988275527954,
#   'neg_sentiment': 1.0},
#  '2011-12-31': {'edit_count': 2,
#   'sentiment': 0.0030662119388580322,
#   'neg_sentiment': 0.5},
#  '2012-01-01': {'edit_count': 1,
#   'sentiment': -0.9986787438392639,
#   'neg_sentiment': 1.0},
#  '2012-01-03': {'edit_count': 2,
#   'sentiment': -0.8125869035720825,
#   'neg_sentiment': 1.0},
#  '2012-01-04': {'edit_count': 2,
#   'sentiment': 0.7446588277816772,
#   'neg_sentiment': 0.0},
#  '2012-01-05': {'edit_count': 3,
#   'sentiment': 0.12725496292114258,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-01-08': {'edit_count': 2,
#   'sentiment': -0.11616316437721252,
#   'neg_sentiment': 0.5},
#  '2012-01-09': {'edit_count': 5,
#   'sentiment': -0.598012363910675,
#   'neg_sentiment': 0.8},
#  '2012-01-10': {'edit_count': 10,
#   'sentiment': -0.5917281687259675,
#   'neg_sentiment': 0.8},
#  '2012-01-12': {'edit_count': 2,
#   'sentiment': -0.13156458735466003,
#   'neg_sentiment': 0.5},
#  '2012-01-14': {'edit_count': 2,
#   'sentiment': -0.11901259422302246,
#   'neg_sentiment': 0.5},
#  '2012-01-16': {'edit_count': 7,
#   'sentiment': -0.13442106757845199,
#   'neg_sentiment': 0.5714285714285714},
#  '2012-01-17': {'edit_count': 8,
#   'sentiment': -0.5066686272621155,
#   'neg_sentiment': 0.75},
#  '2012-01-19': {'edit_count': 3,
#   'sentiment': 0.2328815460205078,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-01-21': {'edit_count': 2,
#   'sentiment': 0.0015774071216583252,
#   'neg_sentiment': 0.5},
#  '2012-01-22': {'edit_count': 1,
#   'sentiment': -0.985650360584259,
#   'neg_sentiment': 1.0},
#  '2012-01-24': {'edit_count': 6,
#   'sentiment': -0.981029212474823,
#   'neg_sentiment': 1.0},
#  '2012-01-26': {'edit_count': 2,
#   'sentiment': 0.004887372255325317,
#   'neg_sentiment': 0.5},
#  '2012-01-28': {'edit_count': 2,
#   'sentiment': -0.02355322241783142,
#   'neg_sentiment': 0.5},
#  '2012-02-01': {'edit_count': 3,
#   'sentiment': -0.9548492232958475,
#   'neg_sentiment': 1.0},
#  '2012-02-03': {'edit_count': 2,
#   'sentiment': 0.7683698832988739,
#   'neg_sentiment': 0.0},
#  '2012-02-05': {'edit_count': 1,
#   'sentiment': -0.9974821209907532,
#   'neg_sentiment': 1.0},
#  '2012-02-07': {'edit_count': 2,
#   'sentiment': 0.0005960166454315186,
#   'neg_sentiment': 0.5},
#  '2012-02-08': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2012-02-09': {'edit_count': 2,
#   'sentiment': -0.9905492067337036,
#   'neg_sentiment': 1.0},
#  '2012-02-11': {'edit_count': 2,
#   'sentiment': -0.9969708621501923,
#   'neg_sentiment': 1.0},
#  '2012-02-12': {'edit_count': 2,
#   'sentiment': 1.3113021850585938e-05,
#   'neg_sentiment': 0.5},
#  '2012-02-13': {'edit_count': 4,
#   'sentiment': -0.005407020449638367,
#   'neg_sentiment': 0.5},
#  '2012-02-14': {'edit_count': 2,
#   'sentiment': -0.12408918142318726,
#   'neg_sentiment': 0.5},
#  '2012-02-16': {'edit_count': 2,
#   'sentiment': -0.1481838822364807,
#   'neg_sentiment': 0.5},
#  '2012-02-17': {'edit_count': 1,
#   'sentiment': -0.9860801100730896,
#   'neg_sentiment': 1.0},
#  '2012-02-18': {'edit_count': 4,
#   'sentiment': -0.8176415264606476,
#   'neg_sentiment': 1.0},
#  '2012-02-19': {'edit_count': 6,
#   'sentiment': -0.3430990974108378,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-02-20': {'edit_count': 3,
#   'sentiment': 0.7674246430397034,
#   'neg_sentiment': 0.0},
#  '2012-02-21': {'edit_count': 3,
#   'sentiment': -0.40921276807785034,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-02-23': {'edit_count': 2,
#   'sentiment': 0.05482691526412964,
#   'neg_sentiment': 0.5},
#  '2012-02-24': {'edit_count': 1,
#   'sentiment': -0.9939278364181519,
#   'neg_sentiment': 1.0},
#  '2012-02-25': {'edit_count': 1,
#   'sentiment': -0.7921814322471619,
#   'neg_sentiment': 1.0},
#  '2012-02-28': {'edit_count': 2,
#   'sentiment': 0.8440593183040619,
#   'neg_sentiment': 0.0},
#  '2012-02-29': {'edit_count': 2,
#   'sentiment': -0.9982721209526062,
#   'neg_sentiment': 1.0},
#  '2012-03-01': {'edit_count': 1,
#   'sentiment': 0.7407251596450806,
#   'neg_sentiment': 0.0},
#  '2012-03-03': {'edit_count': 13,
#   'sentiment': -0.3259496184495779,
#   'neg_sentiment': 0.6923076923076923},
#  '2012-03-04': {'edit_count': 1,
#   'sentiment': 0.927129328250885,
#   'neg_sentiment': 0.0},
#  '2012-03-05': {'edit_count': 3,
#   'sentiment': 0.3039202888806661,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-08': {'edit_count': 2,
#   'sentiment': -0.9409900903701782,
#   'neg_sentiment': 1.0},
#  '2012-03-09': {'edit_count': 4,
#   'sentiment': 0.9320851117372513,
#   'neg_sentiment': 0.0},
#  '2012-03-11': {'edit_count': 1,
#   'sentiment': 0.9726091623306274,
#   'neg_sentiment': 0.0},
#  '2012-03-12': {'edit_count': 9,
#   'sentiment': -0.19166645076539782,
#   'neg_sentiment': 0.5555555555555556},
#  '2012-03-16': {'edit_count': 2,
#   'sentiment': -0.003813803195953369,
#   'neg_sentiment': 0.5},
#  '2012-03-17': {'edit_count': 1,
#   'sentiment': 0.9955694079399109,
#   'neg_sentiment': 0.0},
#  '2012-03-18': {'edit_count': 3,
#   'sentiment': 0.32707573970158893,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-19': {'edit_count': 3,
#   'sentiment': 0.474010169506073,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-20': {'edit_count': 1,
#   'sentiment': 0.9981282353401184,
#   'neg_sentiment': 0.0},
#  '2012-03-21': {'edit_count': 1,
#   'sentiment': 0.9874131679534912,
#   'neg_sentiment': 0.0},
#  '2012-03-22': {'edit_count': 1,
#   'sentiment': -0.7921814322471619,
#   'neg_sentiment': 1.0},
#  '2012-03-23': {'edit_count': 6,
#   'sentiment': -0.388191024462382,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-03-29': {'edit_count': 1,
#   'sentiment': 0.951126754283905,
#   'neg_sentiment': 0.0},
#  '2012-04-01': {'edit_count': 4,
#   'sentiment': -0.5594567805528641,
#   'neg_sentiment': 0.75},
#  '2012-04-02': {'edit_count': 4,
#   'sentiment': 0.4000922739505768,
#   'neg_sentiment': 0.25},
#  '2012-04-03': {'edit_count': 3,
#   'sentiment': 0.8511455655097961,
#   'neg_sentiment': 0.0},
#  '2012-04-05': {'edit_count': 6,
#   'sentiment': -0.9715924461682638,
#   'neg_sentiment': 1.0},
#  '2012-04-06': {'edit_count': 6,
#   'sentiment': -0.04684362808863322,
#   'neg_sentiment': 0.5},
#  '2012-04-07': {'edit_count': 1,
#   'sentiment': -0.999650239944458,
#   'neg_sentiment': 1.0},
#  '2012-04-08': {'edit_count': 7,
#   'sentiment': -0.3672706825392587,
#   'neg_sentiment': 0.7142857142857143},
#  '2012-04-09': {'edit_count': 3,
#   'sentiment': -0.3766917983690898,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-04-10': {'edit_count': 2,
#   'sentiment': 0.7975426316261292,
#   'neg_sentiment': 0.0},
#  '2012-04-13': {'edit_count': 8,
#   'sentiment': -0.27054760605096817,
#   'neg_sentiment': 0.625},
#  '2012-04-15': {'edit_count': 1,
#   'sentiment': -0.9997593760490417,
#   'neg_sentiment': 1.0},
#  '2012-04-17': {'edit_count': 2,
#   'sentiment': -0.8937893509864807,
#   'neg_sentiment': 1.0},
#  '2012-04-18': {'edit_count': 1,
#   'sentiment': 0.927129328250885,
#   'neg_sentiment': 0.0},
#  '2012-04-20': {'edit_count': 1,
#   'sentiment': -0.9608961343765259,
#   'neg_sentiment': 1.0},
#  '2012-04-23': {'edit_count': 4,
#   'sentiment': -0.5571877360343933,
#   'neg_sentiment': 0.75},
#  '2012-04-24': {'edit_count': 1,
#   'sentiment': -0.9994528889656067,
#   'neg_sentiment': 1.0},
#  '2012-04-30': {'edit_count': 1,
#   'sentiment': 0.6861265301704407,
#   'neg_sentiment': 0.0},
#  '2012-05-02': {'edit_count': 3,
#   'sentiment': -0.9965261220932007,
#   'neg_sentiment': 1.0},
#  '2012-05-03': {'edit_count': 1,
#   'sentiment': -0.7921814322471619,
#   'neg_sentiment': 1.0},
#  '2012-05-04': {'edit_count': 2,
#   'sentiment': -0.1831565499305725,
#   'neg_sentiment': 0.5},
#  '2012-05-06': {'edit_count': 1,
#   'sentiment': 0.6268854737281799,
#   'neg_sentiment': 0.0},
#  '2012-05-07': {'edit_count': 3,
#   'sentiment': 0.23814002672831217,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-05-12': {'edit_count': 3,
#   'sentiment': 0.274782399336497,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-05-15': {'edit_count': 5,
#   'sentiment': -0.21651008129119872,
#   'neg_sentiment': 0.6},
#  '2012-05-16': {'edit_count': 1,
#   'sentiment': -0.9989104270935059,
#   'neg_sentiment': 1.0},
#  '2012-05-17': {'edit_count': 3,
#   'sentiment': -0.37239283323287964,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-05-18': {'edit_count': 1,
#   'sentiment': 0.9902607798576355,
#   'neg_sentiment': 0.0},
#  '2012-05-21': {'edit_count': 1,
#   'sentiment': -0.9982331991195679,
#   'neg_sentiment': 1.0},
#  '2012-05-22': {'edit_count': 1,
#   'sentiment': -0.9419381022453308,
#   'neg_sentiment': 1.0},
#  '2012-05-23': {'edit_count': 1,
#   'sentiment': 0.6268854737281799,
#   'neg_sentiment': 0.0},
#  '2012-05-25': {'edit_count': 4,
#   'sentiment': 0.3615092784166336,
#   'neg_sentiment': 0.25},
#  '2012-05-26': {'edit_count': 3,
#   'sentiment': 0.7712299227714539,
#   'neg_sentiment': 0.0},
#  '2012-05-28': {'edit_count': 2,
#   'sentiment': -0.09117013216018677,
#   'neg_sentiment': 0.5},
#  '2012-05-30': {'edit_count': 2,
#   'sentiment': -0.9615827202796936,
#   'neg_sentiment': 1.0},
#  '2012-06-01': {'edit_count': 3,
#   'sentiment': 0.16555331150690714,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-06-02': {'edit_count': 1,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2012-06-03': {'edit_count': 1,
#   'sentiment': -0.9889057874679565,
#   'neg_sentiment': 1.0},
#  '2012-06-04': {'edit_count': 2,
#   'sentiment': -0.9980162978172302,
#   'neg_sentiment': 1.0},
#  '2012-06-05': {'edit_count': 5,
#   'sentiment': 0.5632962346076965,
#   'neg_sentiment': 0.2},
#  '2012-06-08': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2012-06-09': {'edit_count': 3,
#   'sentiment': -0.35383864243825275,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-06-10': {'edit_count': 4,
#   'sentiment': -0.9982579350471497,
#   'neg_sentiment': 1.0},
#  '2012-06-11': {'edit_count': 1,
#   'sentiment': -0.9955434203147888,
#   'neg_sentiment': 1.0},
#  '2012-06-13': {'edit_count': 2,
#   'sentiment': -0.03418689966201782,
#   'neg_sentiment': 0.5},
#  '2012-06-14': {'edit_count': 1,
#   'sentiment': -0.9148892164230347,
#   'neg_sentiment': 1.0},
#  '2012-06-15': {'edit_count': 3,
#   'sentiment': -0.3288454016049703,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-06-21': {'edit_count': 1,
#   'sentiment': 0.7481209635734558,
#   'neg_sentiment': 0.0},
#  '2012-06-22': {'edit_count': 1,
#   'sentiment': 0.7485924959182739,
#   'neg_sentiment': 0.0},
#  '2012-06-24': {'edit_count': 1,
#   'sentiment': -0.9975455403327942,
#   'neg_sentiment': 1.0},
#  '2012-06-25': {'edit_count': 2,
#   'sentiment': -0.12583839893341064,
#   'neg_sentiment': 0.5},
#  '2012-06-26': {'edit_count': 1,
#   'sentiment': -0.9438227415084839,
#   'neg_sentiment': 1.0},
#  '2012-06-27': {'edit_count': 3,
#   'sentiment': 0.2783481280008952,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-06-28': {'edit_count': 2,
#   'sentiment': -0.1161142885684967,
#   'neg_sentiment': 0.5},
#  '2012-06-29': {'edit_count': 2,
#   'sentiment': -0.031747132539749146,
#   'neg_sentiment': 0.5},
#  '2012-06-30': {'edit_count': 6,
#   'sentiment': -0.010006268819173178,
#   'neg_sentiment': 0.5},
#  '2012-07-01': {'edit_count': 6,
#   'sentiment': -0.9052089750766754,
#   'neg_sentiment': 1.0},
#  '2012-07-02': {'edit_count': 3,
#   'sentiment': -0.9996555844942728,
#   'neg_sentiment': 1.0},
#  '2012-07-03': {'edit_count': 3,
#   'sentiment': -0.46123701333999634,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-07-06': {'edit_count': 2,
#   'sentiment': -0.008378267288208008,
#   'neg_sentiment': 0.5},
#  '2012-07-07': {'edit_count': 1,
#   'sentiment': -0.99940025806427,
#   'neg_sentiment': 1.0},
#  '2012-07-08': {'edit_count': 2,
#   'sentiment': -0.1258155107498169,
#   'neg_sentiment': 0.5},
#  '2012-07-10': {'edit_count': 4,
#   'sentiment': -0.4813992530107498,
#   'neg_sentiment': 0.75},
#  '2012-07-11': {'edit_count': 1,
#   'sentiment': -0.8584815859794617,
#   'neg_sentiment': 1.0},
#  '2012-07-12': {'edit_count': 1,
#   'sentiment': -0.7035769820213318,
#   'neg_sentiment': 1.0},
#  '2012-07-13': {'edit_count': 2,
#   'sentiment': -0.9802582561969757,
#   'neg_sentiment': 1.0},
#  '2012-07-16': {'edit_count': 2,
#   'sentiment': -0.034831851720809937,
#   'neg_sentiment': 0.5},
#  '2012-07-18': {'edit_count': 3,
#   'sentiment': -0.9255267977714539,
#   'neg_sentiment': 1.0},
#  '2012-07-19': {'edit_count': 1,
#   'sentiment': 0.9482848048210144,
#   'neg_sentiment': 0.0},
#  '2012-07-20': {'edit_count': 1,
#   'sentiment': -0.974304735660553,
#   'neg_sentiment': 1.0},
#  '2012-07-21': {'edit_count': 3,
#   'sentiment': -0.9984828035036722,
#   'neg_sentiment': 1.0},
#  '2012-07-22': {'edit_count': 1,
#   'sentiment': -0.998062789440155,
#   'neg_sentiment': 1.0},
#  '2012-07-31': {'edit_count': 5,
#   'sentiment': -0.9929562330245971,
#   'neg_sentiment': 1.0},
#  '2012-08-01': {'edit_count': 2,
#   'sentiment': -0.9969570934772491,
#   'neg_sentiment': 1.0},
#  '2012-08-02': {'edit_count': 3,
#   'sentiment': 0.7891600926717123,
#   'neg_sentiment': 0.0},
#  '2012-08-03': {'edit_count': 2,
#   'sentiment': -0.949650764465332,
#   'neg_sentiment': 1.0},
#  '2012-08-06': {'edit_count': 3,
#   'sentiment': 0.3299106955528259,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-08-07': {'edit_count': 6,
#   'sentiment': -0.6505016485850016,
#   'neg_sentiment': 0.8333333333333334},
#  '2012-08-08': {'edit_count': 2,
#   'sentiment': -0.12275373935699463,
#   'neg_sentiment': 0.5},
#  '2012-08-10': {'edit_count': 2,
#   'sentiment': -0.12417414784431458,
#   'neg_sentiment': 0.5},
#  '2012-08-13': {'edit_count': 2,
#   'sentiment': -0.9970331490039825,
#   'neg_sentiment': 1.0},
#  '2012-08-14': {'edit_count': 1,
#   'sentiment': 0.6268854737281799,
#   'neg_sentiment': 0.0},
#  '2012-08-15': {'edit_count': 153,
#   'sentiment': 0.38882595729204567,
#   'neg_sentiment': 0.22875816993464052},
#  '2012-08-16': {'edit_count': 10,
#   'sentiment': -0.11283777952194214,
#   'neg_sentiment': 0.5},
#  '2012-08-17': {'edit_count': 5,
#   'sentiment': 0.16002888679504396,
#   'neg_sentiment': 0.4},
#  '2012-08-18': {'edit_count': 8,
#   'sentiment': -0.9846624508500099,
#   'neg_sentiment': 1.0},
#  '2012-08-19': {'edit_count': 4,
#   'sentiment': -0.5884188711643219,
# ...
#  '2014-01-12': {'edit_count': 12,
#   'sentiment': -0.3625997205575307,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-01-13': {'edit_count': 5,
#   'sentiment': -0.19357000589370726,
#   'neg_sentiment': 0.6},
#  '2014-01-14': {'edit_count': 8,
#   'sentiment': -0.5688725933432579,
#   'neg_sentiment': 0.75},
#  '2014-01-15': {'edit_count': 8,
#   'sentiment': -0.9877667352557182,
#   'neg_sentiment': 1.0},
#  '2014-01-16': {'edit_count': 19,
#   'sentiment': -0.20532235973759702,
#   'neg_sentiment': 0.5789473684210527},
#  '2014-01-17': {'edit_count': 15,
#   'sentiment': -0.7313326994578043,
#   'neg_sentiment': 0.8666666666666667},
#  '2014-01-18': {'edit_count': 2,
#   'sentiment': -0.9962698519229889,
#   'neg_sentiment': 1.0},
#  '2014-01-19': {'edit_count': 5,
#   'sentiment': -0.6185719132423401,
#   'neg_sentiment': 0.8},
#  '2014-01-20': {'edit_count': 17,
#   'sentiment': -0.6720190714387333,
#   'neg_sentiment': 0.8235294117647058},
#  '2014-01-21': {'edit_count': 26,
#   'sentiment': -0.3627751973959116,
#   'neg_sentiment': 0.6923076923076923},
#  '2014-01-22': {'edit_count': 8,
#   'sentiment': -0.7295096218585968,
#   'neg_sentiment': 0.875},
#  '2014-01-23': {'edit_count': 9,
#   'sentiment': -0.5481151143709818,
#   'neg_sentiment': 0.7777777777777778},
#  '2014-01-24': {'edit_count': 4,
#   'sentiment': -0.9580042362213135,
#   'neg_sentiment': 1.0},
#  '2014-01-25': {'edit_count': 14,
#   'sentiment': -0.704279146024159,
#   'neg_sentiment': 0.8571428571428571},
#  '2014-01-26': {'edit_count': 3,
#   'sentiment': 0.3239345947901408,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-01-27': {'edit_count': 19,
#   'sentiment': 0.04062932729721069,
#   'neg_sentiment': 0.47368421052631576},
#  '2014-01-28': {'edit_count': 44,
#   'sentiment': -0.49125538901849225,
#   'neg_sentiment': 0.75},
#  '2014-01-29': {'edit_count': 36,
#   'sentiment': -0.368622299697664,
#   'neg_sentiment': 0.6944444444444444},
#  '2014-01-30': {'edit_count': 20,
#   'sentiment': -0.5056377053260803,
#   'neg_sentiment': 0.75},
#  '2014-01-31': {'edit_count': 7,
#   'sentiment': 0.11740853956767491,
#   'neg_sentiment': 0.42857142857142855},
#  '2014-02-01': {'edit_count': 3,
#   'sentiment': -0.2894427180290222,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-02': {'edit_count': 2,
#   'sentiment': -0.97986900806427,
#   'neg_sentiment': 1.0},
#  '2014-02-03': {'edit_count': 2,
#   'sentiment': -0.029288053512573242,
#   'neg_sentiment': 0.5},
#  '2014-02-04': {'edit_count': 4,
#   'sentiment': -0.5030262023210526,
#   'neg_sentiment': 0.75},
#  '2014-02-05': {'edit_count': 6,
#   'sentiment': -0.3314637939135234,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-06': {'edit_count': 14,
#   'sentiment': -0.41523613248552593,
#   'neg_sentiment': 0.7142857142857143},
#  '2014-02-07': {'edit_count': 3,
#   'sentiment': -0.32986851533253986,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-08': {'edit_count': 12,
#   'sentiment': -0.14855014781157175,
#   'neg_sentiment': 0.5833333333333334},
#  '2014-02-09': {'edit_count': 6,
#   'sentiment': -0.653343657652537,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-02-10': {'edit_count': 5,
#   'sentiment': -0.5181595683097839,
#   'neg_sentiment': 0.8},
#  '2014-02-11': {'edit_count': 16,
#   'sentiment': -0.9769332855939865,
#   'neg_sentiment': 1.0},
#  '2014-02-12': {'edit_count': 9,
#   'sentiment': -0.992360876666175,
#   'neg_sentiment': 1.0},
#  '2014-02-13': {'edit_count': 11,
#   'sentiment': -0.4849506670778448,
#   'neg_sentiment': 0.7272727272727273},
#  '2014-02-14': {'edit_count': 9,
#   'sentiment': -0.9364738398128085,
#   'neg_sentiment': 1.0},
#  '2014-02-15': {'edit_count': 3,
#   'sentiment': -0.9974373579025269,
#   'neg_sentiment': 1.0},
#  '2014-02-16': {'edit_count': 6,
#   'sentiment': -0.6640868584314982,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-02-17': {'edit_count': 4,
#   'sentiment': -0.49974024295806885,
#   'neg_sentiment': 0.75},
#  '2014-02-19': {'edit_count': 3,
#   'sentiment': -0.3088587721188863,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-21': {'edit_count': 3,
#   'sentiment': -0.9966362913449606,
#   'neg_sentiment': 1.0},
#  '2014-02-22': {'edit_count': 2,
#   'sentiment': -0.01267436146736145,
#   'neg_sentiment': 0.5},
#  '2014-02-23': {'edit_count': 1,
#   'sentiment': -0.9707514643669128,
#   'neg_sentiment': 1.0},
#  '2014-02-24': {'edit_count': 1,
#   'sentiment': -0.9905113577842712,
#   'neg_sentiment': 1.0},
#  '2014-02-25': {'edit_count': 11,
#   'sentiment': -0.44504334168000653,
#   'neg_sentiment': 0.7272727272727273},
#  '2014-02-26': {'edit_count': 8,
#   'sentiment': -0.9863354787230492,
#   'neg_sentiment': 1.0},
#  '2014-02-27': {'edit_count': 2,
#   'sentiment': -0.9991008937358856,
#   'neg_sentiment': 1.0},
#  '2014-02-28': {'edit_count': 3,
#   'sentiment': -0.33364689350128174,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-03-01': {'edit_count': 29,
#   'sentiment': -0.5178193264994128,
#   'neg_sentiment': 0.7586206896551724},
#  '2014-03-02': {'edit_count': 10,
#   'sentiment': -0.5971071243286132,
#   'neg_sentiment': 0.8},
#  '2014-03-03': {'edit_count': 8,
#   'sentiment': 0.2180531993508339,
#   'neg_sentiment': 0.375},
#  '2014-03-04': {'edit_count': 14,
#   'sentiment': -0.07287228533199855,
#   'neg_sentiment': 0.5},
#  '2014-03-05': {'edit_count': 28,
#   'sentiment': -0.875477135181427,
#   'neg_sentiment': 0.9285714285714286},
#  '2014-03-06': {'edit_count': 26,
#   'sentiment': -0.8906702857751113,
#   'neg_sentiment': 0.9615384615384616},
#  '2014-03-07': {'edit_count': 17,
#   'sentiment': -0.5486810522920945,
#   'neg_sentiment': 0.7647058823529411},
#  '2014-03-08': {'edit_count': 25,
#   'sentiment': -0.6967321419715882,
#   'neg_sentiment': 0.84},
#  '2014-03-09': {'edit_count': 12,
#   'sentiment': -0.8042902598778406,
#   'neg_sentiment': 0.9166666666666666},
#  '2014-03-10': {'edit_count': 18,
#   'sentiment': -0.8799353043238322,
#   'neg_sentiment': 0.9444444444444444},
#  '2014-03-11': {'edit_count': 29,
#   'sentiment': -0.7291559618094872,
#   'neg_sentiment': 0.8620689655172413},
#  '2014-03-12': {'edit_count': 18,
#   'sentiment': -0.7740959326426188,
#   'neg_sentiment': 0.8888888888888888},
#  '2014-03-13': {'edit_count': 19,
#   'sentiment': -0.5863955240500601,
#   'neg_sentiment': 0.7894736842105263},
#  '2014-03-14': {'edit_count': 8,
#   'sentiment': -0.960588701069355,
#   'neg_sentiment': 1.0},
#  '2014-03-15': {'edit_count': 7,
#   'sentiment': -0.7515904647963387,
#   'neg_sentiment': 0.8571428571428571},
#  '2014-03-16': {'edit_count': 1,
#   'sentiment': -0.9995993971824646,
#   'neg_sentiment': 1.0},
#  '2014-03-17': {'edit_count': 12,
#   'sentiment': -0.5197486331065496,
#   'neg_sentiment': 0.75},
#  '2014-03-18': {'edit_count': 15,
#   'sentiment': -0.5682886997858684,
#   'neg_sentiment': 0.8},
#  '2014-03-19': {'edit_count': 20,
#   'sentiment': -0.6367604076862335,
#   'neg_sentiment': 0.8},
#  '2014-03-20': {'edit_count': 25,
#   'sentiment': -0.682227189540863,
#   'neg_sentiment': 0.84},
#  '2014-03-21': {'edit_count': 19,
#   'sentiment': -0.26737749576568604,
#   'neg_sentiment': 0.631578947368421},
#  '2014-03-22': {'edit_count': 12,
#   'sentiment': 0.2827630937099457,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-03-23': {'edit_count': 24,
#   'sentiment': -0.7468098998069763,
#   'neg_sentiment': 0.875},
#  '2014-03-24': {'edit_count': 1,
#   'sentiment': -0.9668272733688354,
#   'neg_sentiment': 1.0},
#  '2014-03-25': {'edit_count': 18,
#   'sentiment': -0.1506270468235016,
#   'neg_sentiment': 0.5555555555555556},
#  '2014-03-26': {'edit_count': 11,
#   'sentiment': -0.6365213339978998,
#   'neg_sentiment': 0.8181818181818182},
#  '2014-03-27': {'edit_count': 9,
#   'sentiment': -0.21980937321980795,
#   'neg_sentiment': 0.5555555555555556},
#  '2014-03-28': {'edit_count': 43,
#   'sentiment': -0.5981738151505936,
#   'neg_sentiment': 0.7906976744186046},
#  '2014-03-29': {'edit_count': 16,
#   'sentiment': -0.704131942242384,
#   'neg_sentiment': 0.875},
#  '2014-03-30': {'edit_count': 38,
#   'sentiment': -0.4484737123313703,
#   'neg_sentiment': 0.7105263157894737},
#  '2014-03-31': {'edit_count': 22,
#   'sentiment': -0.8101093579422344,
#   'neg_sentiment': 0.9090909090909091},
#  '2014-04-01': {'edit_count': 29,
#   'sentiment': 0.034427219423754464,
#   'neg_sentiment': 0.4482758620689655},
#  '2014-04-02': {'edit_count': 53,
#   'sentiment': -0.4888776754433254,
#   'neg_sentiment': 0.7358490566037735},
#  '2014-04-03': {'edit_count': 9,
#   'sentiment': -0.5863241420851814,
#   'neg_sentiment': 0.7777777777777778},
#  '2014-04-04': {'edit_count': 36,
#   'sentiment': -0.5125319163004557,
#   'neg_sentiment': 0.75},
#  '2014-04-05': {'edit_count': 1,
#   'sentiment': -0.9993261098861694,
#   'neg_sentiment': 1.0},
#  '2014-04-06': {'edit_count': 2,
#   'sentiment': -0.005591362714767456,
#   'neg_sentiment': 0.5},
#  '2014-04-07': {'edit_count': 13,
#   'sentiment': 0.17066053243783805,
#   'neg_sentiment': 0.38461538461538464},
#  '2014-04-08': {'edit_count': 8,
#   'sentiment': 0.4292137175798416,
#   'neg_sentiment': 0.25},
#  '2014-04-09': {'edit_count': 16,
#   'sentiment': -0.7389367185533047,
#   'neg_sentiment': 0.875},
#  '2014-04-10': {'edit_count': 6,
#   'sentiment': 0.1288446287314097,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-04-11': {'edit_count': 8,
#   'sentiment': 0.12287267297506332,
#   'neg_sentiment': 0.375},
#  '2014-04-12': {'edit_count': 7,
#   'sentiment': -0.404937139579228,
#   'neg_sentiment': 0.7142857142857143},
#  '2014-04-13': {'edit_count': 15,
#   'sentiment': -0.8522641142209371,
#   'neg_sentiment': 0.9333333333333333},
#  '2014-04-14': {'edit_count': 8,
#   'sentiment': -0.745801642537117,
#   'neg_sentiment': 0.875},
#  '2014-04-15': {'edit_count': 27,
#   'sentiment': -0.4525492279617875,
#   'neg_sentiment': 0.7037037037037037},
#  '2014-04-16': {'edit_count': 47,
#   'sentiment': -0.47192036471468335,
#   'neg_sentiment': 0.723404255319149},
#  '2014-04-17': {'edit_count': 20,
#   'sentiment': -0.6488602608442307,
#   'neg_sentiment': 0.85},
#  '2014-04-18': {'edit_count': 119,
#   'sentiment': -0.7310651605870543,
#   'neg_sentiment': 0.8739495798319328},
#  '2014-04-19': {'edit_count': 62,
#   'sentiment': -0.7448469717656413,
#   'neg_sentiment': 0.8709677419354839},
#  '2014-04-20': {'edit_count': 28,
#   'sentiment': -0.5880080355065209,
#   'neg_sentiment': 0.7857142857142857},
#  '2014-04-21': {'edit_count': 36,
#   'sentiment': -0.7804076870282491,
#   'neg_sentiment': 0.8888888888888888},
#  '2014-04-22': {'edit_count': 8,
#   'sentiment': -0.5116523429751396,
#   'neg_sentiment': 0.75},
#  '2014-04-23': {'edit_count': 8,
#   'sentiment': -0.18353213369846344,
#   'neg_sentiment': 0.625},
#  '2014-04-24': {'edit_count': 23,
#   'sentiment': -0.7484410560649374,
#   'neg_sentiment': 0.8695652173913043},
#  '2014-04-25': {'edit_count': 11,
#   'sentiment': -0.12028048797087236,
#   'neg_sentiment': 0.5454545454545454},
#  '2014-04-26': {'edit_count': 11,
#   'sentiment': -0.18580976941368796,
#   'neg_sentiment': 0.5454545454545454},
#  '2014-04-27': {'edit_count': 16,
#   'sentiment': -0.6409318782389164,
#   'neg_sentiment': 0.8125},
#  '2014-04-28': {'edit_count': 7,
#   'sentiment': -0.7251837509019035,
#   'neg_sentiment': 0.8571428571428571},
#  '2014-04-29': {'edit_count': 8,
#   'sentiment': 0.3512446880340576,
#   'neg_sentiment': 0.25},
#  '2014-04-30': {'edit_count': 1,
#   'sentiment': -0.996650755405426,
#   'neg_sentiment': 1.0},
#  '2014-05-01': {'edit_count': 31,
#   'sentiment': -0.8357691072648571,
#   'neg_sentiment': 0.9354838709677419},
#  '2014-05-02': {'edit_count': 27,
#   'sentiment': -0.5058015518718295,
#   'neg_sentiment': 0.7407407407407407},
#  '2014-05-04': {'edit_count': 7,
#   'sentiment': -0.9619986585208348,
#   'neg_sentiment': 1.0},
#  '2014-05-05': {'edit_count': 15,
#   'sentiment': -0.45596808195114136,
#   'neg_sentiment': 0.7333333333333333},
#  '2014-05-06': {'edit_count': 5,
#   'sentiment': -0.20001842975616455,
#   'neg_sentiment': 0.6},
#  '2014-05-07': {'edit_count': 27,
#   'sentiment': -0.008066881586004186,
#   'neg_sentiment': 0.48148148148148145},
#  '2014-05-08': {'edit_count': 23,
#   'sentiment': -0.3747589691825535,
#   'neg_sentiment': 0.6956521739130435},
#  '2014-05-09': {'edit_count': 23,
#   'sentiment': -0.5738177999206211,
#   'neg_sentiment': 0.782608695652174},
#  '2014-05-10': {'edit_count': 27,
#   'sentiment': -0.3979686631096734,
#   'neg_sentiment': 0.7037037037037037},
#  '2014-05-11': {'edit_count': 18,
#   'sentiment': -0.48326027062204147,
#   'neg_sentiment': 0.7222222222222222},
#  '2014-05-12': {'edit_count': 17,
#   'sentiment': -0.7546615670709049,
#   'neg_sentiment': 0.8823529411764706},
#  '2014-05-13': {'edit_count': 11,
#   'sentiment': -0.8121917572888461,
#   'neg_sentiment': 0.9090909090909091},
#  '2014-05-14': {'edit_count': 7,
#   'sentiment': -0.4826355576515198,
#   'neg_sentiment': 0.7142857142857143},
#  '2014-05-15': {'edit_count': 5,
#   'sentiment': -0.20148347616195678,
#   'neg_sentiment': 0.6},
#  '2014-05-16': {'edit_count': 10,
#   'sentiment': 0.3065006136894226,
#   'neg_sentiment': 0.3},
#  '2014-05-17': {'edit_count': 6,
#   'sentiment': -0.08653958638509114,
#   'neg_sentiment': 0.5},
#  '2014-05-18': {'edit_count': 5,
#   'sentiment': -0.6137194514274598,
#   'neg_sentiment': 0.8},
#  '2014-05-19': {'edit_count': 12,
#   'sentiment': -0.3961380322774251,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-05-20': {'edit_count': 8,
#   'sentiment': -0.24308564513921738,
#   'neg_sentiment': 0.625},
#  '2014-05-21': {'edit_count': 40,
#   'sentiment': -0.4453905761241913,
#   'neg_sentiment': 0.7},
#  '2014-05-25': {'edit_count': 4,
#   'sentiment': -0.9908394068479538,
#   'neg_sentiment': 1.0},
#  '2014-05-26': {'edit_count': 16,
#   'sentiment': -0.623298067599535,
#   'neg_sentiment': 0.8125},
#  '2014-05-27': {'edit_count': 23,
#   'sentiment': -0.724428679632104,
#   'neg_sentiment': 0.8695652173913043},
#  '2014-05-29': {'edit_count': 4,
#   'sentiment': -0.5470228791236877,
#   'neg_sentiment': 0.75},
#  '2014-05-30': {'edit_count': 7,
#   'sentiment': -0.9435908879552569,
#   'neg_sentiment': 1.0},
#  '2014-05-31': {'edit_count': 6,
#   'sentiment': -0.6646863718827566,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-06-01': {'edit_count': 13,
#   'sentiment': -0.534419059753418,
#   'neg_sentiment': 0.7692307692307693},
#  '2014-06-02': {'edit_count': 8,
#   'sentiment': -0.31411702185869217,
#   'neg_sentiment': 0.625},
#  '2014-06-03': {'edit_count': 12,
#   'sentiment': -0.6949236045281092,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-06-04': {'edit_count': 14,
#   'sentiment': -0.8139528504439763,
#   'neg_sentiment': 0.9285714285714286},
#  '2014-06-06': {'edit_count': 2,
#   'sentiment': -0.1210346519947052,
#   'neg_sentiment': 0.5},
#  '2014-06-07': {'edit_count': 2,
#   'sentiment': 0.9300208687782288,
#   'neg_sentiment': 0.0},
#  '2014-06-08': {'edit_count': 10,
#   'sentiment': -0.41407981514930725,
#   'neg_sentiment': 0.7},
#  '2014-06-09': {'edit_count': 4,
#   'sentiment': 0.47864337265491486,
#   'neg_sentiment': 0.25},
#  '2014-06-10': {'edit_count': 7,
#   'sentiment': -0.21231128488268172,
#   'neg_sentiment': 0.5714285714285714},
#  '2014-06-11': {'edit_count': 7,
#   'sentiment': -0.9776390450341361,
#   'neg_sentiment': 1.0},
#  '2014-06-12': {'edit_count': 4,
#   'sentiment': 0.3740563541650772,
#   'neg_sentiment': 0.25},
#  '2014-06-13': {'edit_count': 11,
#   'sentiment': -0.4965491078116677,
#   'neg_sentiment': 0.7272727272727273},
#  '2014-06-15': {'edit_count': 14,
#   'sentiment': 0.002244374581745693,
#   'neg_sentiment': 0.5},
#  '2014-06-16': {'edit_count': 1,
#   'sentiment': 0.7185574173927307,
#   'neg_sentiment': 0.0},
#  '2014-06-17': {'edit_count': 2,
#   'sentiment': 0.017641305923461914,
#   'neg_sentiment': 0.5},
#  '2014-06-18': {'edit_count': 6,
#   'sentiment': -0.048440645138422646,
#   'neg_sentiment': 0.5},
#  '2014-06-19': {'edit_count': 1,
#   'sentiment': -0.9971330165863037,
#   'neg_sentiment': 1.0},
#  '2014-06-20': {'edit_count': 9,
#   'sentiment': -0.5853277775976393,
#   'neg_sentiment': 0.7777777777777778},
#  '2014-06-21': {'edit_count': 1,
#   'sentiment': -0.9982319474220276,
#   'neg_sentiment': 1.0},
#  '2014-06-23': {'edit_count': 1,
#   'sentiment': -0.9704646468162537,
#   'neg_sentiment': 1.0},
#  '2014-06-24': {'edit_count': 3,
#   'sentiment': -0.9891806046168009,
#   'neg_sentiment': 1.0},
#  '2014-06-25': {'edit_count': 1,
#   'sentiment': -0.9990149736404419,
#   'neg_sentiment': 1.0},
#  '2014-06-26': {'edit_count': 6,
#   'sentiment': -0.27050084869066876,
#   'neg_sentiment': 0.6666666666666666},
#  ...}

# %%
from statistics import mean

for key in edits:
    if len(edits[key]["sentiments"]) > 0:
        edits[key]["sentiment"] = mean(edits[key]["sentiments"])
        edits[key]["neg_sentiment"] = len([s for s in edits[key]["sentiments"] if s < 0]) / len(edits[key]["sentiments"])
    else:
        edits[key]["sentiment"] = 0
        edits[key]["neg_sentiment"] = 0
    
    del edits[key]["sentiments"]

# %%
import pandas as pd

edits_df = pd.DataFrame.from_dict(edits, orient="index")

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-03-08           4  -0.550525       0.750000
# 2009-08-05           1   0.748121       0.000000
# 2009-08-06           2   0.995746       0.000000
# 2009-08-14           1   0.930021       0.000000
# 2009-10-13           2  -0.227501       0.500000
# ...                ...        ...            ...
# 2023-01-26           3  -0.322411       0.666667
# 2023-01-28           1  -0.999590       1.000000
# 2023-01-30           1  -0.998388       1.000000
# 2023-02-08           1  -0.539562       1.000000
# 2023-02-17           3  -0.466066       0.666667
#
# [2574 rows x 3 columns]

# %%
edits_df.index = pd.to_datetime(edits_df.index)

# %%
from datetime import datetime

dates = pd.date_range(start="2009-03-08",end=datetime.today())

# %%
edits_df = edits_df.reindex(dates, fill_value=0)

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-03-08           4  -0.550525       0.750000
# 2009-03-09           0   0.000000       0.000000
# 2009-03-10           0   0.000000       0.000000
# 2009-03-11           0   0.000000       0.000000
# 2009-03-12           0   0.000000       0.000000
# ...                ...        ...            ...
# 2023-02-14           0   0.000000       0.000000
# 2023-02-15           0   0.000000       0.000000
# 2023-02-16           0   0.000000       0.000000
# 2023-02-17           3  -0.466066       0.666667
# 2023-02-18           0   0.000000       0.000000
#
# [5096 rows x 3 columns]

# %%
rolling_edits = edits_df.rolling(30, min_periods=30).mean()

# %%
rolling_edits = rolling_edits.dropna()

# %%
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.133333  -0.018351       0.025000
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2023-02-14    0.600000  -0.144895       0.245556
# 2023-02-15    0.600000  -0.144895       0.245556
# 2023-02-16    0.600000  -0.144895       0.245556
# 2023-02-17    0.666667  -0.127558       0.234444
# 2023-02-18    0.600000  -0.123756       0.217778
#
# [5067 rows x 3 columns]

# %%
rolling_edits.to_csv("wikipedia_edits.csv")

# %%
sentiment_pipeline('Bitcoin is correlated to nasdaq')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9739328026771545}]

# %%
find_sentiment('what an asshole')
# Out:
# -0.999405026435852
